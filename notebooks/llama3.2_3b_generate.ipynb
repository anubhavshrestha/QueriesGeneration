# %%
import torch
import gc
import os

# First, clear all CUDA memory and cache
torch.cuda.empty_cache()
gc.collect()

# Print initial GPU info
print("Initial GPU setup:")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"GPU {i}: {props.name} ({props.total_memory / 1024**2:.0f}MB)")

# Set the 3090 Ti (find it by memory size ~24GB)
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    if props.total_memory > 20000 * 2**20:  # More than 20GB = 3090 Ti
        os.environ["CUDA_VISIBLE_DEVICES"] = str(i)
        torch.cuda.set_device(0)  # After setting VISIBLE_DEVICES, it becomes device 0
        print(f"\nSet RTX 3090 Ti (device {i}) as the active device")
        break

# Verify current device
print(f"\nCurrent active device: {torch.cuda.get_device_name()}")
# Out:
# Initial GPU setup:
# GPU 0: NVIDIA GeForce RTX 3090 Ti (24245MB)
# GPU 1: NVIDIA GeForce GT 1030 (2000MB)
#
# Set RTX 3090 Ti (device 0) as the active device
#
# Current active device: NVIDIA GeForce RTX 3090 Ti

# %%
from unsloth import FastLanguageModel
import torch
import time
import os

# Clear any existing CUDA memory
torch.cuda.empty_cache()

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-3B-Instruct",
    max_seq_length=512,
    dtype=None,
    load_in_4bit=True,
)

FastLanguageModel.for_inference(model)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.47.0.
#    \\   /|    GPU: NVIDIA GeForce RTX 3090 Ti. Max memory: 23.677 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 3072, padding_idx=128004)
#     (layers): ModuleList(
#       (0-27): 28 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
#           (k_proj): Linear4bit(in_features=3072, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=3072, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
#           (rotary_emb): LlamaExtendedRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=3072, out_features=8192, bias=False)
#           (up_proj): Linear4bit(in_features=3072, out_features=8192, bias=False)
#           (down_proj): Linear4bit(in_features=8192, out_features=3072, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((3072,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((3072,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=3072, out_features=128256, bias=False)
# )

# %%
def process_tsv_and_generate(input_file, output_dir="queries3b", num_lines=1000):
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    with open(input_file, 'r', encoding='utf-8') as f:
        for i in range(num_lines):
            line = f.readline().strip()
            if not line:
                break
                
            # Split line into doc_id and document
            try:
                doc_id, document = line.split('\t', 1)
            except ValueError:
                print(f"Skipping malformed line {i}")
                continue
            
            # Generate queries
            prompt = f"Generate one relevant query for this passage:\n\n{document}. Do not produce anything else."
            
            messages = [
                {"role": "user", "content": prompt},
            ]
            
            start_time = time.time()
            
            inputs = tokenizer.apply_chat_template(
                messages,
                tokenize=True,
                add_generation_prompt=True,
                return_tensors="pt"
            ).to("cuda")
            
            outputs = model.generate(
                input_ids=inputs,
                max_new_tokens=50,
                num_return_sequences=80,
                temperature=0.9,
                top_k=50,
                do_sample=True,
                use_cache=True,
                pad_token_id=tokenizer.pad_token_id if tokenizer.pad_token_id is not None else tokenizer.eos_token_id,
            )
            
            results = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
            
            # Save to individual file for this doc_id
            output_file = os.path.join(output_dir, f"queries_{doc_id}.txt")
            with open(output_file, 'w', encoding='utf-8') as out_f:
                for j, result in enumerate(results, 1):
                    out_f.write(f"Output {j}:\n{result}\n{'-' * 50}\n")
                out_f.write(f"\nExecution time: {time.time() - start_time:.2f} seconds\n")
            
            print(f"Processed document {doc_id} ({i+1}/{num_lines})")
            
            # Optional: Clear GPU memory periodically
            if i % 10 == 0:
                torch.cuda.empty_cache()

# Run the processing
input_file = "/drive_reader/as16386/Datasets/msmarco-2018.tsv"
process_tsv_and_generate(input_file)
# Out:
# Processed document 0 (1/1000)
# Processed document 1 (2/1000)
# Processed document 2 (3/1000)
# Processed document 3 (4/1000)
# Processed document 4 (5/1000)
# Processed document 5 (6/1000)
# Processed document 6 (7/1000)
# Processed document 7 (8/1000)
# Processed document 8 (9/1000)
# Processed document 9 (10/1000)
# Processed document 10 (11/1000)
# Processed document 11 (12/1000)
# Processed document 12 (13/1000)
# Processed document 13 (14/1000)
# Processed document 14 (15/1000)
# Processed document 15 (16/1000)
# Processed document 16 (17/1000)
# Processed document 17 (18/1000)
# Processed document 18 (19/1000)
# Processed document 19 (20/1000)
# Processed document 20 (21/1000)
# Processed document 21 (22/1000)
# Processed document 22 (23/1000)
# Processed document 23 (24/1000)
# Processed document 24 (25/1000)
# Processed document 25 (26/1000)
# Processed document 26 (27/1000)
# Processed document 27 (28/1000)
# Processed document 28 (29/1000)
# Processed document 29 (30/1000)
# Processed document 30 (31/1000)
# Processed document 31 (32/1000)
# Processed document 32 (33/1000)
# Processed document 33 (34/1000)
# Processed document 34 (35/1000)
# Processed document 35 (36/1000)
# Processed document 36 (37/1000)
# Processed document 37 (38/1000)
# Processed document 38 (39/1000)
# Processed document 39 (40/1000)
# Processed document 40 (41/1000)
# Processed document 41 (42/1000)
# Processed document 42 (43/1000)
# Processed document 43 (44/1000)
# Processed document 44 (45/1000)
# Processed document 45 (46/1000)
# Processed document 46 (47/1000)
# Processed document 47 (48/1000)
# Processed document 48 (49/1000)
# Processed document 49 (50/1000)
# Processed document 50 (51/1000)
# Processed document 51 (52/1000)
# Processed document 52 (53/1000)
# Processed document 53 (54/1000)
# Processed document 54 (55/1000)
# Processed document 55 (56/1000)
# Processed document 56 (57/1000)
# Processed document 57 (58/1000)
# Processed document 58 (59/1000)
# Processed document 59 (60/1000)
# Processed document 60 (61/1000)
# Processed document 61 (62/1000)
# Processed document 62 (63/1000)
# Processed document 63 (64/1000)
# Processed document 64 (65/1000)
# Processed document 65 (66/1000)
# Processed document 66 (67/1000)
# Processed document 67 (68/1000)
# Processed document 68 (69/1000)
# Processed document 69 (70/1000)
# Processed document 70 (71/1000)
# Processed document 71 (72/1000)
# Processed document 72 (73/1000)
# Processed document 73 (74/1000)
# Processed document 74 (75/1000)
# Processed document 75 (76/1000)
# Processed document 76 (77/1000)
# Processed document 77 (78/1000)
# Processed document 78 (79/1000)
# Processed document 79 (80/1000)
# Processed document 80 (81/1000)
# Processed document 81 (82/1000)
# Processed document 82 (83/1000)
# Processed document 83 (84/1000)
# Processed document 84 (85/1000)
# Processed document 85 (86/1000)
# Processed document 86 (87/1000)
# Processed document 976 (977/1000)
# Processed document 977 (978/1000)
# Processed document 978 (979/1000)
# Processed document 979 (980/1000)
# Processed document 980 (981/1000)
# Processed document 981 (982/1000)
# Processed document 982 (983/1000)
# Processed document 983 (984/1000)
# Processed document 984 (985/1000)
# Processed document 985 (986/1000)
# Processed document 986 (987/1000)
# Processed document 987 (988/1000)
# Processed document 988 (989/1000)
# Processed document 989 (990/1000)
# Processed document 990 (991/1000)
# Processed document 991 (992/1000)
# Processed document 992 (993/1000)
# Processed document 993 (994/1000)
# Processed document 994 (995/1000)
# Processed document 995 (996/1000)
# Processed document 996 (997/1000)
# Processed document 997 (998/1000)
# Processed document 998 (999/1000)
# Processed document 999 (1000/1000)

# %% [markdown]
# # average time: 2.331 passage / second

# %%
from unsloth import FastLanguageModel
import torch
import time
import os

# Clear any existing CUDA memory
torch.cuda.empty_cache()

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Llama-3.2-1B-Instruct",
    max_seq_length=512,
    dtype=None,
    load_in_4bit=True,
)

FastLanguageModel.for_inference(model)

def generate_queries(passage):
    prompt = f"Generate one relevant query for this passage:\n\n{passage}. Do not produce anything else."
    
    messages = [
        {"role": "user", "content": prompt},
    ]
    
    start_time = time.time()
    
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize=True,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to("cuda")
    
    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=50,
        num_return_sequences=40,
        temperature=0.9,
        top_k=50,
        do_sample=True,
        use_cache=True,
        pad_token_id=tokenizer.pad_token_id if tokenizer.pad_token_id is not None else tokenizer.eos_token_id,
    )
    
    results = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    
    end_time = time.time()
    print(f"\nExecution time: {time.time() - start_time:.2f} seconds")
    
    return results

# Example usage
test_passage = """Claude is an AI assistant created by Anthropic.
    It aims to be helpful while being direct and honest about its capabilities.
    It can assist with analysis, writing, math, coding and various other tasks."""

results = generate_queries(test_passage)

# Print raw outputs
print("\nRAW OUTPUTS:")
print("=" * 50)
for i, raw_output in enumerate(results, 1):
    print(f"\nOutput {i}:")
    print(raw_output)
    print("-" * 50)
# Out:
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.47.0.
#    \\   /|    GPU: NVIDIA GeForce RTX 3090 Ti. Max memory: 23.677 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.6. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
#
# Execution time: 0.55 seconds
#
# RAW OUTPUTS:
# ==================================================
#
# Output 1:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What is the primary function of Claude, an AI assistant created by Anthropic?
# --------------------------------------------------
#
# Output 2:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "Can Claude assist with writing math and coding tasks?"
# --------------------------------------------------
#
# Output 3:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Is it possible to identify what Claude AI assistant is capable of?
# --------------------------------------------------
#
# Output 4:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What capabilities does Anthropic's AI assistant offer?
# --------------------------------------------------
#
# Output 5:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What AI assistant is being created by Anthropic?
# --------------------------------------------------
#
# Output 6:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Here's a query that's relevant to the passage:
#
# "What tasks can an Anthropic AI assistant assist with?"
# --------------------------------------------------
#
# Output 7:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Here's a relevant query based on the passage:
#
# "What can an AI assistant like Anthropic do?"
# --------------------------------------------------
#
# Output 8:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What type of tasks does Claude assist with?
# --------------------------------------------------
#
# Output 9:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What AI assistant created by Anthropic is Claude?
# --------------------------------------------------
#
# Output 10:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What type of tasks does Claude assist with?
# --------------------------------------------------
#
# Output 11:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Is Anthropic an AI assistant that can assist with math tasks?
# --------------------------------------------------
#
# Output 12:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Is the following query relevant to the passage: What AI assistant created by Anthropic can assist with writing?
# --------------------------------------------------
#
# Output 13:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Is Claude an AI assistant created by Anthropic?
# --------------------------------------------------
#
# Output 14:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What can Claude, an AI assistant, assist with?
# --------------------------------------------------
#
# Output 15:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "Which AI assistant, created by Anthropic, can assist with analysis, writing, math, coding, and various other tasks?"
# --------------------------------------------------
#
# Output 16:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What Claude can do?
# --------------------------------------------------
#
# Output 17:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What AI assistant is Claude?
# --------------------------------------------------
#
# Output 18:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "Which Anthropic AI assistant is Claude?"
# --------------------------------------------------
#
# Output 19:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "Which AI assistant is created by Anthropic and aims to be direct and honest about its capabilities?"
# --------------------------------------------------
#
# Output 20:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What Claude AI assistant is capable of?
# --------------------------------------------------
#
# Output 21:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "Which AI assistant created by Anthropic is being used for tasks such as analysis, writing, math, coding and other activities?"
# --------------------------------------------------
#
# Output 22:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Here's a relevant query for the passage:
#
# "What capabilities does Claude AI assistant have?"
# --------------------------------------------------
#
# Output 23:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "What tasks can Claude assist with?"
# --------------------------------------------------
#
# Output 24:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What AI assistant does Claude assist with?
# --------------------------------------------------
#
# Output 25:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Can Anthropic's AI assistant, Claude, assist with creative writing and storytelling tasks?
# --------------------------------------------------
#
# Output 26:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Here's a query for the passage:
#
# Can you describe the AI assistant created by Anthropic?
# --------------------------------------------------
#
# Output 27:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Is there a specific task or request for which Claude, the AI assistant, is being asked to provide assistance?
# --------------------------------------------------
#
# Output 28:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# "Created by Anthropic, a digital AI assistant capable of assisting with various tasks including analysis, writing, math, coding and more."
# --------------------------------------------------
#
# Output 29:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Here's a relevant query for the given passage:
#
# "What capabilities does Anthropic AI assistant have, and what tasks can it assist with?"
# --------------------------------------------------
#
# Output 30:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What can Claude assist with?
# --------------------------------------------------
#
# Output 31:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What Claude AI assistant can assist with?
# --------------------------------------------------
#
# Output 32:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What AI assistant does Claude aim to be helpful and honest with its capabilities?
# --------------------------------------------------
#
# Output 33:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Can Claude assist me with a mathematical problem?
# --------------------------------------------------
#
# Output 34:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What task is Claude assisting with?
# --------------------------------------------------
#
# Output 35:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What AI assistant is Claude?
# --------------------------------------------------
#
# Output 36:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What type of task is Claude most helpful for?
# --------------------------------------------------
#
# Output 37:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Which AI assistant is Claude?
# --------------------------------------------------
#
# Output 38:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# What Claude is an AI assistant created by Anthropic.
# --------------------------------------------------
#
# Output 39:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Is there an AI assistant created by Anthropic that can assist with analysis, writing, math, coding, and various other tasks?
# --------------------------------------------------
#
# Output 40:
# system
#
# Cutting Knowledge Date: December 2023
# Today Date: 20 Jan 2025
#
# user
#
# Generate one relevant query for this passage:
#
# Claude is an AI assistant created by Anthropic.
#     It aims to be helpful while being direct and honest about its capabilities.
#     It can assist with analysis, writing, math, coding and various other tasks.. Do not produce anything else.assistant
#
# Here's a relevant query for the given passage:
#
# "Anthropic AI assistant capabilities"
# --------------------------------------------------
