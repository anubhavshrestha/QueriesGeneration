# %%
# Set this at the very start of your notebook
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Use RTX 3090 Ti

# Now import other libraries
import torch
import gc

# Clear GPU memory
torch.cuda.empty_cache()
gc.collect()

# Verify we're using the right GPU
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Device count: {torch.cuda.device_count()}")
print(f"Device name: {torch.cuda.get_device_name(0)}")
print(f"Total memory: {torch.cuda.get_device_properties(0).total_memory / (1024**3):.1f} GB")
# Out:
# CUDA available: True
# Device count: 1
# Device name: NVIDIA GeForce RTX 3090 Ti
# Total memory: 23.7 GB

# %%
# !pip install unsloth transformers datasets tqdm accelerate bitsandbytes
# Out:
# Requirement already satisfied: unsloth in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (2025.3.18)
# Requirement already satisfied: transformers in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (4.48.2)
# Requirement already satisfied: datasets in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: tqdm in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: accelerate in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: bitsandbytes in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (0.45.0)
# Requirement already satisfied: requests in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: filelock in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: pyyaml>=5.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (0.26.5)
# Requirement already satisfied: safetensors>=0.4.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: numpy>=1.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: xxhash in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: aiohttp in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (3.11.10)
# Requirement already satisfied: multiprocess<0.70.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (2024.9.0)
# Requirement already satisfied: torch>=1.10.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: psutil in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: typing_extensions>=4.8.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.3.1.170)
# Requirement already satisfied: sympy==1.13.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.21.5)
# Requirement already satisfied: jinja2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.5.8)
# Requirement already satisfied: networkx in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)

# %%
import os
import torch
import random
import numpy as np
from datasets import Dataset
from tqdm.notebook import tqdm


from transformers import TrainingArguments, DataCollatorForSeq2Seq
from trl import SFTTrainer

# Set random seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
# Set the path to your document-query TSV file
data_path = "/drive_reader/as16386/collections/msmarco-passage/document-query-pairs.train.tsv"  # Adjust this path

# Function to load a sample of data from the TSV file
def load_doc_query_sample(file_path, num_samples=2000):
    documents = []
    queries = []
    
    with open(file_path, 'r', encoding='utf-8') as f:
        # Read all lines and randomly sample
        lines = f.readlines()
        
        # Randomly sample num_samples lines
        if len(lines) > num_samples:
            lines = random.sample(lines, num_samples)
        
        for line in tqdm(lines, desc="Loading data"):
            parts = line.strip().split('\t')
            if len(parts) == 2:
                documents.append(parts[0])
                queries.append(parts[1])
    
    return {"document": documents, "query": queries}

# Load a small sample of data
sample_data = load_doc_query_sample(data_path, num_samples=2000)
dataset = Dataset.from_dict(sample_data)

# Let's see a few examples
print(f"Loaded {len(dataset)} document-query pairs")
print("\nExample 1:")
print(f"Document: {dataset[0]['document'][:200]}...")
print(f"Query: {dataset[0]['query']}")

print("\nExample 2:")
print(f"Document: {dataset[1]['document'][:200]}...")
print(f"Query: {dataset[1]['query']}")
# Out:
# Loading data:   0%|          | 0/2000 [00:00<?, ?it/s]
# Loaded 2000 document-query pairs
#
# Example 1:
# Document: Diabetes also can causes problems with blood flow ... The ulcer itself is usually caused by: Repetitive trauma or pressure on the foot; Puncture wound on the foot; Objects in the ... Tell your doctor ...
# Query: what causes legs to swell and acne and have blisters
#
# Example 2:
# Document: However, many fans can recall that shows do not get cancelled because of ratings alone. According to the publication, Blue Bloods Season 7 may be its last or close to the finale because the production...
# Query: was blue bloods cancelled

# %%
# Training

import torch
import random
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM, 
    AutoTokenizer, 
    BitsAndBytesConfig,
    TrainingArguments,
    DataCollatorForSeq2Seq,
    Trainer
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from tqdm.auto import tqdm

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Model configuration
MODEL_NAME = "meta-llama/Llama-3.2-1B-Instruct"  # or "meta-llama/Llama-3.2-1B-Instruct" for smaller model
OUTPUT_DIR = "doc2query-llama-3.2"
MAX_LENGTH = 512  # Maximum sequence length

# Format data for instruction fine-tuning
def generate_prompt(document, query=None):
    """Format the document and query into an instruction prompt."""
    if query:
        # For training examples with both document and expected query
        return f"[INST] Generate a search query for this document: {document} [/INST] {query}"
    else:
        # For inference (query generation)
        return f"[INST] Generate a search query for this document: {document} [/INST]"

def preprocess_function(examples):
    """Process multiple examples in the dataset."""
    prompts = [generate_prompt(doc, query) for doc, query in zip(examples["document"], examples["query"])]
    
    # Tokenize the examples
    tokenized_inputs = tokenizer(
        prompts,
        truncation=True,
        max_length=MAX_LENGTH,
        padding="max_length",
        return_tensors=None  # Change to None instead of "pt" - let the Dataset handle conversion
    )
    
    # Create labels (using list copying instead of tensor copying)
    tokenized_inputs["labels"] = [ids.copy() for ids in tokenized_inputs["input_ids"]]
    
    # Mask out the loss for the instruction part
    for i, prompt in enumerate(prompts):
        instruction_pos = prompt.find("[/INST]") + len("[/INST]")
        instruction_text = prompt[:instruction_pos]
        # Tokenize just the instruction part to find its length
        instruction_ids = tokenizer(instruction_text, add_special_tokens=False)["input_ids"]
        instruction_tok_len = len(instruction_ids)
        
        # Set the instruction part labels to -100 (ignore in loss calculation)
        tokenized_inputs["labels"][i][:instruction_tok_len] = [-100] * instruction_tok_len
    
    return tokenized_inputs

# Load tokenizer
print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Process dataset
print("Processing dataset...")
processed_dataset = dataset.map(
    preprocess_function,
    batched=True,
    remove_columns=dataset.column_names,
    desc="Processing dataset",
)

# Configure 4-bit quantization
print("Configuring quantization...")
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# Load model with quantization
print("Loading model...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
)

# Prepare model for training
print("Preparing model for training...")
model = prepare_model_for_kbit_training(model)

# LoRA configuration
peft_config = LoraConfig(
    r=16,  # Rank of the update matrices
    lora_alpha=32,  # Parameter for scaling
    lora_dropout=0.05,  # Dropout probability for LoRA layers
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",  # Attention matrices
        "gate_proj", "up_proj", "down_proj"      # MLP matrices
    ],
    bias="none",
    task_type="CAUSAL_LM",
)

# Apply LoRA
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# Configure training arguments
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=2,  # Adjust based on your GPU memory
    gradient_accumulation_steps=8,
    learning_rate=2e-4,
    num_train_epochs=3,
    logging_steps=10,
    save_steps=100,
    save_total_limit=3,
    warmup_ratio=0.03,
    lr_scheduler_type="cosine",
    report_to="none",  # Can use "tensorboard" or "wandb"
    bf16=True if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8 else False,
    gradient_checkpointing=True,
    fp16=False,
    optim="paged_adamw_32bit",
)

# Define data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    pad_to_multiple_of=8,
    return_tensors="pt"
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=processed_dataset,
    data_collator=data_collator,
)

# Start training
print("Starting training...")
trainer.train()

# Save the model
print(f"Saving model to {OUTPUT_DIR}")
model.save_pretrained(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# 1. Load the fine-tuned model and tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = "/drive_reader/as16386/github/models/doc2query-llama-1b"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path)

# Load base model with same quantization as training
model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-3.2-1B-Instruct",
    quantization_config=BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    ),
    device_map="auto",
)

# Load the LoRA weights
model = PeftModel.from_pretrained(model, model_path)
model.eval()

# 2. Define a function to generate multiple queries
def generate_multiple_queries(document, num_queries=80, max_new_tokens=30):
    prompt = f"[INST] Generate a search query for this document: {document} [/INST]"
    
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    
    # Set pad token id to eos token id if not set
    if model.config.pad_token_id is None:
        model.config.pad_token_id = model.config.eos_token_id
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=True,
            temperature=0.85,  # Slightly higher temperature for diversity
            top_p=0.92,
            top_k=50,
            num_return_sequences=num_queries,  # Generate multiple sequences
            num_beams=1,  # Must be 1 when using num_return_sequences with do_sample=True
            return_dict_in_generate=True,
            output_scores=False
        )
    
    generated_texts = tokenizer.batch_decode(outputs.sequences, skip_special_tokens=True)
    
    # Extract just the generated responses (after the instruction)
    responses = [text.split("[/INST]")[1].strip() for text in generated_texts]
    return responses

# 3. Test with one document from your dataset
# Choose an interesting document from your dataset
test_document = dataset[0]["document"]  # You could pick any index that has an interesting document
print(f"Document: {test_document[:200]}...\n")  # Show just the beginning to save space

# Generate 80 possible queries
queries = generate_multiple_queries(test_document, num_queries=80)

# Print the results
print(f"Generated {len(queries)} alternative queries:")
for i, query in enumerate(queries):
    print(f"{i+1}. {query}")

# 4. Optional: Save results to file
with open("generated_queries.txt", "w") as f:
    f.write(f"DOCUMENT:\n{test_document}\n\nGENERATED QUERIES:\n")
    for i, query in enumerate(queries):
        f.write(f"{i+1}. {query}\n")

print("\nQueries also saved to 'generated_queries.txt'")
# Out:
# /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/peft/config.py:162: UserWarning: Unexpected keyword arguments ['corda_config', 'trainable_token_indices'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Document: Diabetes also can causes problems with blood flow ... The ulcer itself is usually caused by: Repetitive trauma or pressure on the foot; Puncture wound on the foot; Objects in the ... Tell your doctor ...
# From v4.47 onwards, when a model cache is to be returned, `generate` will return a `Cache` instance instead by default (as opposed to the legacy tuple of tuples format). If you want to keep returning the legacy format, please set `return_legacy_cache=True`.
# Generated 80 alternative queries:
# 1. does diabetes cause foot ulcers
# 2. what causes ulcers in your leg
# 3. what can cause blistering of feet and legs
# 4. what causes skin blisters and ulcers
# 5. what causes soreness in lower leg
# 6. causes of foot pain with ulcers
# 7. what causes blisters on the legs
# 8. what causes blood flow to legs to swell
# 9. what causes pain and swelling in the legs
# 10. what is causing my feet to hurt
# 11. what causes sunburn on lower leg
# 12. what causes ulcers in the feet
# 13. what causes pain in feet and ankles
# 14. causes of foot ulcers
# 15. what can cause blistering and pain in the feet
# 16. what causes ulcers on your feet
# 17. what causes painful sores on legs and feet
# 18. what causes sores on the foot
# 19. does tanning bed cause blisters
# 20. what causes sores and blisters on the feet
# 21. can uv light cause foot pain
# 22. can uv light cause foot pain
# 23. what causes foot ulcer
# 24. can sunlamps cause swelling in the legs
# 25. what cause sunburn
# 26. what causes a foot ulcer
# 27. what causes sunburn in the foot
# 28. what causes blisters on your foot
# 29. what can cause a sore on your foot
# 30. can uv light cause foot pain
# 31. what causes blisters on the feet
# 32. what causes foot pain and ulcers
# 33. what causes pain in the lower leg and foot
# 34. can pressure ulcers cause sunburn
# 35. what are causes of foot ulcers
# 36. causes of foot and leg pain and swelling
# 37. what causes sunburn on lower leg
# 38. can skin cancer cause ulcers
# 39. what causes sunburn on feet and legs
# 40. can a tanning bed cause foot pain
# 41. what can cause a sore on my foot
# 42. what causes foot pain and blisters
# 43. what causes blister on bottom of foot
# 44. what causes blister on the foot
# 45. what cause a foot ulcer
# 46. what causes sore blisters on feet
# 47. causes of sores in feet
# 48. what causes skin ulcers and what helps
# 49. what causes sores in the foot
# 50. causes of pain and swelling on the bottom of the foot
# 51. can a wound cause pain
# 52. what causes sores in the foot
# 53. what causes sunburn of leg
# 54. can uv light cause pain
# 55. does the sun cause soreness
# 56. can tanning beds cause sores on the foot
# 57. what causes sunburn in feet
# 58. what causes painful sores on your feet
# 59. what can cause a sore on the bottom of my foot
# 60. what causes blisters on foot
# 61. what causes sunburn pain
# 62. what causes blisters on feet
# 63. can sunburn cause foot pain
# 64. what causes a sore in the foot
# 65. can uv rays cause blisters
# 66. what causes sores on the foot
# 67. symptoms of skin sores on the foot
# 68. what causes foot to swell and skin to blister
# 69. symptoms of pressure ulcer
# 70. what causes blisters in the foot
# 71. what causes foot ulcers
# 72. what causes blister on foot
# 73. what causes blisters in the feet
# 74. what causes soreness and pain in foot
# 75. can sunlamps cause blisters
# 76. what causes pain in the bottom of the foot
# 77. what causes blisters and pain in the foot
# 78. can skin cancer cause ulcers
# 79. can diabetes cause foot problems
# 80. does uv light cause blisters
#
# Queries also saved to 'generated_queries.txt'

# %% [markdown]
# # LORA Inference

# %%
# VLLM INFERENCE
# Install VLLM
# pip install vllm

from vllm import LLM, SamplingParams

# Step 1: Merge your LoRA weights with the base model (one-time operation)
from peft import PeftModel
import torch

# Load models
base_model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-3.2-1B-Instruct", 
    torch_dtype=torch.float16,
    device_map="auto"
)
lora_model = PeftModel.from_pretrained(base_model, "/drive_reader/as16386/github/models/doc2query-llama-1b")

# Merge and save
merged_model = lora_model.merge_and_unload()
merged_model.save_pretrained("doc2query-llama-3.2-merged")
tokenizer.save_pretrained("doc2query-llama-3.2-merged")

# Step 2: Use VLLM for fast inference
llm = LLM(model="doc2query-llama-3.2-merged", dtype="float16")

# For single document
def generate_query_vllm(document):
    prompt = f"[INST] Generate a search query for this document: {document} [/INST]"
    sampling_params = SamplingParams(temperature = 0.9, top_p=0.95, top_k = 50, max_tokens=50)
    outputs = llm.generate(prompt, sampling_params)
    response = outputs[0].outputs[0].text.strip()
    return response

# For batch processing - VLLM really shines here!
def batch_generate_queries_vllm(documents, num_queries=1):
    prompts = [f"[INST] Generate a search query for this document: {doc} [/INST]" for doc in documents]
    sampling_params = SamplingParams(
        temperature=0.9,
        top_p=0.95, 
        top_k = 50,
        max_tokens=50,
        n=num_queries  # Generate multiple queries per document
    )
    outputs = llm.generate(prompts, sampling_params)
    
    results = []
    for output in outputs:
        document_queries = [out.text.strip() for out in output.outputs]
        results.append(document_queries)
    
    return results
# Out:
# Some parameters are on the meta device because they were offloaded to the cpu.
# /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/peft/config.py:162: UserWarning: Unexpected keyword arguments ['corda_config', 'trainable_token_indices'] for class LoraConfig, these are ignored. This probably means that you're loading a configuration file that was saved using a higher version of the library and additional parameters have been introduced since. It is highly recommended to upgrade the PEFT version before continuing (e.g. by running `pip install -U peft`).
#   warnings.warn(
# Some parameters are on the meta device because they were offloaded to the cpu.
# /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/transformers/modeling_utils.py:2810: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(
# Saving checkpoint shards:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO 03-29 16:30:31 config.py:350] This model supports multiple tasks: {'embedding', 'generate'}. Defaulting to 'generate'.
# WARNING 03-29 16:30:31 arg_utils.py:1013] Chunked prefill is enabled by default for models with max_model_len > 32K. Currently, chunked prefill might not work with some features or models. If you encounter any issues, please disable chunked prefill by setting --enable-chunked-prefill=False.
# INFO 03-29 16:30:31 config.py:1136] Chunked prefill is enabled with max_num_batched_tokens=512.
# INFO 03-29 16:30:31 llm_engine.py:249] Initializing an LLM engine (v0.6.4.post1) with config: model='doc2query-llama-3.2-merged', speculative_config=None, tokenizer='doc2query-llama-3.2-merged', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=131072, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=doc2query-llama-3.2-merged, num_scheduler_steps=1, chunked_prefill_enabled=True multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, chat_template_text_format=string, mm_processor_kwargs=None, pooler_config=None)
# INFO 03-29 16:30:32 model_runner.py:1072] Starting to load model doc2query-llama-3.2-merged...
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-29 16:30:33 model_runner.py:1077] Loading model weights took 2.3029 GB
# INFO 03-29 16:30:33 worker.py:232] Memory profiling results: total_gpu_memory=23.68GiB initial_memory_usage=22.34GiB peak_torch_memory=22.50GiB memory_usage_post_profile=22.34GiB non_torch_memory=1.00GiB kv_cache_size=-2.19GiB gpu_memory_utilization=0.90
# INFO 03-29 16:30:33 gpu_executor.py:113] # GPU blocks: 0, # CPU blocks: 8192
# INFO 03-29 16:30:33 gpu_executor.py:117] Maximum concurrency for 131072 tokens per request: 0.00x
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 25
#      22 tokenizer.save_pretrained("doc2query-llama-3.2-merged")
#      24 # Step 2: Use VLLM for fast inference
# ---> 25 llm = LLM(model="doc2query-llama-3.2-merged", dtype="float16")
#      27 # For single document
#      28 def generate_query_vllm(document):
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/utils.py:1028, in deprecate_args.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#    1021             msg += f" {additional_message}"
#    1023         warnings.warn(
#    1024             DeprecationWarning(msg),
#    1025             stacklevel=3,  # The inner function takes up one level
#    1026         )
# -> 1028 return fn(*args, **kwargs)
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/entrypoints/llm.py:210, in LLM.__init__(self, model, tokenizer, tokenizer_mode, skip_tokenizer_init, trust_remote_code, allowed_local_media_path, tensor_parallel_size, dtype, quantization, revision, tokenizer_revision, seed, gpu_memory_utilization, swap_space, cpu_offload_gb, enforce_eager, max_seq_len_to_capture, disable_custom_all_reduce, disable_async_output_proc, hf_overrides, mm_processor_kwargs, task, override_pooler_config, **kwargs)
#     207 self.engine_class = self.get_engine_class()
#     209 # TODO(rob): enable mp by default (issue with fork vs spawn)
# --> 210 self.llm_engine = self.engine_class.from_engine_args(
#     211     engine_args, usage_context=UsageContext.LLM_CLASS)
#     213 self.request_counter = Counter()
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/engine/llm_engine.py:585, in LLMEngine.from_engine_args(cls, engine_args, usage_context, stat_loggers)
#     583 executor_class = cls._get_executor_cls(engine_config)
#     584 # Create the LLM engine.
# --> 585 engine = cls(
#     586     vllm_config=engine_config,
#     587     executor_class=executor_class,
#     588     log_stats=not engine_args.disable_log_stats,
#     589     usage_context=usage_context,
#     590     stat_loggers=stat_loggers,
#     591 )
#     593 return engine
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/engine/llm_engine.py:350, in LLMEngine.__init__(self, vllm_config, executor_class, log_stats, usage_context, stat_loggers, input_registry, mm_registry, use_cached_outputs)
#     347 self.model_executor = executor_class(vllm_config=vllm_config, )
#     349 if self.model_config.task != "embedding":
# --> 350     self._initialize_kv_caches()
#     352 # If usage stat is enabled, collect relevant info.
#     353 if is_usage_stats_enabled():
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/engine/llm_engine.py:500, in LLMEngine._initialize_kv_caches(self)
#     497 self.cache_config.num_gpu_blocks = num_gpu_blocks
#     498 self.cache_config.num_cpu_blocks = num_cpu_blocks
# --> 500 self.model_executor.initialize_cache(num_gpu_blocks, num_cpu_blocks)
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/executor/gpu_executor.py:120, in GPUExecutor.initialize_cache(self, num_gpu_blocks, num_cpu_blocks)
#     115 max_concurrency = (num_gpu_blocks * self.cache_config.block_size /
#     116                    self.model_config.max_model_len)
#     117 logger.info("Maximum concurrency for %s tokens per request: %.2fx",
#     118             self.model_config.max_model_len, max_concurrency)
# --> 120 self.driver_worker.initialize_cache(num_gpu_blocks, num_cpu_blocks)
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/worker/worker.py:268, in Worker.initialize_cache(self, num_gpu_blocks, num_cpu_blocks)
#     262 def initialize_cache(self, num_gpu_blocks: int,
#     263                      num_cpu_blocks: int) -> None:
#     264     """Allocate GPU and CPU KV cache with the specified number of blocks.
#     265
#     266     This also warms up the model, which may record CUDA graphs.
#     267     """
# --> 268     raise_if_cache_size_invalid(num_gpu_blocks,
#     269                                 self.cache_config.block_size,
#     270                                 self.cache_config.is_attention_free,
#     271                                 self.model_config.max_model_len)
#     273     self.cache_config.num_gpu_blocks = num_gpu_blocks
#     274     self.cache_config.num_cpu_blocks = num_cpu_blocks
#
# File /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages/vllm/worker/worker.py:493, in raise_if_cache_size_invalid(num_gpu_blocks, block_size, is_attention_free, max_model_len)
#     489     raise ValueError("No memory should be allocated for the cache blocks "
#     490                      f"for an attention-free model, but {num_gpu_blocks}"
#     491                      "blocks are allocated.")
#     492 if not is_attention_free and num_gpu_blocks <= 0:
# --> 493     raise ValueError("No available memory for the cache blocks. "
#     494                      "Try increasing `gpu_memory_utilization` when "
#     495                      "initializing the engine.")
#     496 max_seq_len = block_size * num_gpu_blocks
#     497 if not is_attention_free and max_model_len > max_seq_len:
#
# ValueError: No available memory for the cache blocks. Try increasing `gpu_memory_utilization` when initializing the engine.

# %%
# Test documents (replace with your own examples)
test_documents = [
    "Diabetes also can causes problems with blood flow. The ulcer itself is usually caused by: Repetitive trauma or pressure on the foot; Puncture wound on the foot. Tell your doctor if you have any of these symptoms: Sores, ulcers, or blisters on the foot or lower leg; Pain.",
    
    "However, many fans can recall that shows do not get cancelled because of ratings alone. According to the publication, Blue Bloods Season 7 may be its last or close to the finale because the production costs are getting too high.",
    
    "The Golden State Warriors are an American professional basketball team based in San Francisco. The Warriors compete in the National Basketball Association (NBA), as a member of the league's Western Conference Pacific Division.",
    
    "Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.",
    
    "Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically typed and garbage-collected.",

    "Hypertension, or high blood pressure, can lead to severe health complications if left untreated. Common symptoms include headaches, shortness of breath, and dizziness. Lifestyle changes and medication can help manage the condition effectively.",

    "The latest season of Stranger Things has captivated audiences worldwide. Critics praise its nostalgic 80s references and compelling storytelling. However, some fans argue that the pacing in the latest episodes feels slower compared to previous seasons.",

    "Real Madrid is one of the most successful football clubs in history, boasting multiple UEFA Champions League titles. Known for their attacking playstyle, the club has produced legends like Cristiano Ronaldo, Zinedine Zidane, and Raúl.",

    "Cloud computing allows users to store and access data remotely, reducing dependency on local storage. Major providers like Amazon Web Services (AWS), Google Cloud, and Microsoft Azure dominate the market with their scalable infrastructure.",

    "JavaScript is a versatile programming language used primarily for web development. It enables dynamic interactions on web pages and is supported by all major browsers. Frameworks like React and Angular simplify the development process."




]

# %%
# 2. Test batch processing with multiple queries per document
print("\nBATCH PROCESSING (80 queries per document):")
print("-" * 80)
results = batch_generate_queries_vllm(test_documents, num_queries=80)

for i, doc_queries in enumerate(results):
    print(f"Document {i+1}: {test_documents[i][:100]}...")
    print("Generated queries:")
    for j, query in enumerate(doc_queries):
        print(f"  {j+1}. {query}")
    print("-" * 80)
# Out:
# BATCH PROCESSING (80 queries per document):
# --------------------------------------------------------------------------------
# Processed prompts:   0%|          | 0/800 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts:   1%|▏         | 10/800 [00:02<03:41,  3.57it/s, est. speed input: 207.26 toks/s, output: 1925.99 toks/s]
# Document 1: Diabetes also can causes problems with blood flow. The ulcer itself is usually caused by: Repetitive...
# Generated queries:
#   1. what causes a foot ulcer
#   2. what are the causes of a foot ulcer
#   3. what causes foot ulcers to heal
#   4. what causes an ulcer
#   5. diabetes foot ulcers causes
#   6. symptoms of a foot ulcer
#   7. what causes foot ulcers
#   8. causes of foot ulcers
#   9. what can cause a foot ulcer
#   10. what causes blood to flow in the legs when there is no blood pressure in the body
#   11. what causes blisters on your leg
#   12. can diabetes cause ulcers on legs
#   13. what causes an ulcer?
#   14. what can cause a diabetic ulcer
#   15. diabetes and foot ulcers
#   16. what can cause a sore in your foot
#   17. can diabetes cause foot ulcers
#   18. can diabetes cause foot ulcers
#   19. can diabetes cause foot ulcers
#   20. diabetes causes of foot ulcers
#   21. causes of foot ulcers
#   22. causes of foot ulcers
#   23. what causes a foot ulcer
#   24. causes of ulcers in feet
#   25. causes of foot ulcer
#   26. causes of foot ulcers
#   27. causes of foot ulcers
#   28. what causes foot ulcers
#   29. what causes a sore foot ulcer
#   30. what causes blood flow problems
#   31. causes of a foot ulcer
#   32. what causes foot ulcers
#   33. what causes blisters on feet
#   34. causes of foot ulcers
#   35. what causes blisters on the legs
#   36. diabetes causes and symptoms
#   37. what causes a foot ulcer to form
#   38. what causes foot ulcers in diabetic patients
#   39. what causes foot ulcers
#   40. causes of ulcerative foot
#   41. what causes foot ulcers
#   42. what causes foot ulcers
#   43. causes of foot ulcers
#   44. what causes foot ulcers
#   45. what causes foot ulcers
#   46. can diabetes cause blisters in feet
#   47. symptoms of a foot ulcer
#   48. what causes a foot ulcer
#   49. diabetes symptoms feet
#   50. what causes foot ulcers
#   51. what causes ulcers
#   52. symptoms of blood flow to the feet
#   53. what causes a foot ulcer
#   54. what causes foot ulcers
#   55. foot ulcers causes
#   56. what causes a wound on your leg to go black
#   57. what are the causes of ulcers
#   58. what causes a foot ulcer
#   59. causes of blood flow problems in legs
#   60. diabetes can cause a foot ulcer
#   61. causes of foot ulcers
#   62. causes of ulceration of foot
#   63. can a ulcer on the foot cause leg pain
#   64. what causes ulcers in the feet
#   65. can diabetes cause foot ulcers
#   66. causes of ulcers
#   67. what causes a foot ulcer to heal
#   68. what causes pressure ulcers in the feet
#   69. what causes blisters on your feet
#   70. what causes ulcers on feet
#   71. can diabetes cause foot ulcers
#   72. diabetes symptoms of foot ulcers
#   73. what causes an ulcer on the leg
#   74. what causes foot ulcers
#   75. what can cause foot ulcers
#   76. what causes pressure ulcers in the legs
#   77. foot ulcer causes
#   78. what can cause an ulcer on the leg
#   79. what causes ulcers in legs
#   80. what causes a foot ulcer?
# --------------------------------------------------------------------------------
# Document 2: However, many fans can recall that shows do not get cancelled because of ratings alone. According to...
# Generated queries:
#   1. how many seasons of blue bloods
#   2. how many seasons are blue bloods
#   3. how many seasons of blue bloods are there
#   4. is blue bloods cancelled
#   5. is blue bloods cancelled
#   6. how many seasons of blue bloods are there
#   7. how many seasons are blue bloods going to have
#   8. is blue bloods canceled
#   9. is blue bloods going to be cancelled
#   10. what tv show is cancelled
#   11. blue bloods cancellation
#   12. is blue bloods cancelled
#   13. blue bloods finale number of episodes
#   14. is blue bloods cancelled
#   15. how many seasons of blue bloods are there
#   16. how many seasons are blue bloods going to have
#   17. is blue bloods canceled
#   18. is blue bloods going to be canceled
#   19. how many seasons of blue bloods
#   20. how many seasons of blue bloods are there
#   21. how many seasons of blue bloods
#   22. how many seasons are there of blue bloods
#   23. how many seasons are there in blue bloods
#   24. is blue bloods cancelled
#   25. what shows got cancelled
#   26. how many seasons of blue bloods are there
#   27. how many seasons blue bloods
#   28. what station is blue bloods on
#   29. why did blue bloods get cancelled
#   30. why is blue bloods ending
#   31. is blue bloods cancelled
#   32. is blue bloods cancelled
#   33. is blue bloods getting cancelled
#   34. how many seasons does blue bloods have
#   35. how many seasons is blue bloods going to have
#   36. is blue bloods cancel
#   37. is blue bloods cancelled
#   38. what is blue bloods final season
#   39. why did blue bloods get cancelled
#   40. how many seasons of blue bloods
#   41. how many seasons of blue bloods are there
#   42. how many seasons of blue bloods are there
#   43. what season is blue bloods on
#   44. what season of blue bloods are they canceling
#   45. how many seasons are there in blue bloods
#   46. is blue bloods cancelled
#   47. how many seasons is blue bloods going to have
#   48. what show was cancelled
#   49. how many seasons of blue bloods are there
#   50. is blue bloods cancelled
#   51. is blue bloods cancelled
#   52. what is blue bloods final season
#   53. how many seasons are there in blue bloods
#   54. is blue bloods cancelled
#   55. is blue bloods canceled
#   56. what channel is blue bloods cancelled
#   57. is blue bloods ending
#   58. how many seasons of blue bloods are there
#   59. blue bloods cancelled
#   60. is blue bloods cancelled
#   61. is blue bloods cancelled
#   62. how many seasons are there of blue bloods
#   63. how many seasons of blue bloods are there
#   64. is blue bloods cancelled
#   65. how many seasons are there for blue bloods
#   66. is blue bloods cancel
#   67. how many seasons of blue bloods are there
#   68. what season was blue bloods cancelled
#   69. is blue bloods cancelled
#   70. is blue bloods cancelled
#   71. is blue bloods cancelled
#   72. how many seasons of blue bloods are there
#   73. is blue bloods cancelled
#   74. is blue bloods coming back
#   75. is blue bloods cancelled
#   76. is blue bloods coming back for another season
#   77. how many seasons are there in blue bloods
#   78. how many seasons of blue bloods
#   79. is blue bloods cancelled
#   80. is blue bloods cancelled
# --------------------------------------------------------------------------------
# Document 3: The Golden State Warriors are an American professional basketball team based in San Francisco. The W...
# Generated queries:
#   1. where are the golden state warriors from
#   2. where are golden state warriors based
#   3. where are the golden state warriors from
#   4. what division is the golden state warriors
#   5. where are the golden state warriors
#   6. what state is the golden state warriors from
#   7. what is the golden state warriors
#   8. where do the golden state warriors play
#   9. where are the golden state warriors
#   10. what state are the golden state warriors based in
#   11. what state do the golden state warriors come from
#   12. what conference is the golden state warriors in
#   13. where are the golden state warriors from
#   14. what nba team is based in san francisco
#   15. what are the golden state warriors
#   16. what division is the golden state warriors
#   17. where are the golden state warriors based
#   18. what is the warriors
#   19. what state are the golden state warriors in
#   20. where are the warriors
#   21. where is the golden state warriors
#   22. what division is the golden state warriors
#   23. what conference is the warriors in
#   24. what state are the golden state warriors from
#   25. where is the golden state warriors
#   26. what city are the golden state warriors
#   27. what is the warriors
#   28. where is the golden state warriors
#   29. where is the warriors based
#   30. where are the golden state warriors based
#   31. what state are the golden state warriors from
#   32. what state are the golden state warriors in
#   33. what conference is the golden state warriors in
#   34. where is the golden state warriors
#   35. where is the golden state warriors basketball team based
#   36. where is the warriors located
#   37. what conference is the golden state warriors
#   38. what state is the golden state warriors
#   39. what division is the golden state warriors
#   40. what is the state of the golden state warriors
#   41. where is the golden state warriors basketball team based
#   42. what division are the golden state warriors in
#   43. where do the warriors play
#   44. what is warriors
#   45. what state is warriors
#   46. where do the golden state warriors play
#   47. what conference are golden state warriors
#   48. what state are the golden state warriors from
#   49. what team is golden state warriors
#   50. what state is the golden state warriors from
#   51. what is the warriors
#   52. what division is golden state warriors
#   53. where are the golden state warriors based
#   54. what city is the golden state warriors basketball team
#   55. where are the golden state warriors
#   56. what city is the golden state warriors
#   57. where are the golden state warriors based
#   58. where is the golden state warriors located
#   59. what state do warriors play in
#   60. what state is the golden state warriors
#   61. where is the golden state warriors based
#   62. what conference is the golden state warriors
#   63. where is the golden state warriors located
#   64. what conference is the golden state warriors
#   65. what conference are the golden state warriors in
#   66. what state is warriors
#   67. what league is the golden state warriors
#   68. where are the golden state warriors
#   69. where do the golden state warriors play
#   70. what state is the warriors in
#   71. what state are the golden state warriors from
#   72. where are the golden state warriors based
#   73. what league is the golden state warriors
#   74. what is golden state warriors
#   75. where is the golden state warriors
#   76. where are the golden state warriors from
#   77. what state is the golden state warriors
#   78. where are the warriors basketball team from
#   79. what are the warriors
#   80. what are the warriors
# --------------------------------------------------------------------------------
# Document 4: Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on t...
# Generated queries:
#   1. what is machine learning in ai
#   2. what is machine learning systems
#   3. what is machine learning and how does it work
#   4. what is machine learning and artificial intelligence
#   5. what is machine learning what is it used for
#   6. what does machine learning mean
#   7. what is machine learning ai
#   8. machine learning definition
#   9. what is machine learning used for
#   10. what does machine learning mean
#   11. what is machine learning and artificial intelligence
#   12. what does machine learning mean
#   13. what is machine learning for kids
#   14. what is machine learning used for
#   15. what is a machine learning?
#   16. what is machine learning and how is it different from artificial intelligence
#   17. what is machine learning?
#   18. what is a machine learning program
#   19. what is machine learning
#   20. what does machine learning mean
#   21. what is machine learning?
#   22. what is a machine learning engine
#   23. what is machine learning training
#   24. what is machine learning used for
#   25. what is machine learning in ai
#   26. what is a machine learning
#   27. what is machine learning?
#   28. what is machine learning and ai
#   29. define machine learning in computer science
#   30. what is the use of machine learning
#   31. what is machine learning?
#   32. what is machine learning
#   33. what is a machine learning model
#   34. what is machine learning
#   35. machine learning definition computer
#   36. what is machine learning in computer science
#   37. what is a machine learning
#   38. what is machine learning
#   39. what is machine learning in computer science
#   40. what is machine learning model
#   41. what is machine learning?
#   42. what is machine learning?
#   43. what is machine learning?
#   44. what is machine learning?
#   45. machine learning what does it do
#   46. what is the definition of machine learning?
#   47. what is machine learning in ai
#   48. what is machine learning?
#   49. what is machine learning
#   50. machine learning definition for kids
#   51. what is machine learning used for
#   52. what is a machine learning program
#   53. what is machine learning?
#   54. what is a machine learning
#   55. what is machine learning used for
#   56. what is machine learning software
#   57. what is machine learning
#   58. what is machine learning?
#   59. define machine learning
#   60. what is machine learning
#   61. machine learning definition
#   62. what is machine learning program
#   63. machine learning define
#   64. define machine learning
#   65. what is machine learning in computers
#   66. what is machine learning in data
#   67. what is the learning part of artificial intelligence
#   68. what is machine learning?
#   69. what does machine learning mean
#   70. what is machine learning?
#   71. what does machine learning mean
#   72. what is machine learning
#   73. what does machine learning consist of
#   74. what is the definition of machine learning
#   75. what is a machine learning
#   76. what is machine learning programming
#   77. what is the difference between machine learning and artificial intelligence
#   78. machine learning definition
#   79. what is a machine learning
#   80. what is the definition of machine learning?
# --------------------------------------------------------------------------------
# Document 5: Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code ...
# Generated queries:
#   1. what is python programming
#   2. what is python programming
#   3. what type of programming language is python
#   4. what is python?
#   5. is python a language or programming
#   6. what is a python programming language
#   7. what language is used for data analysis
#   8. what is python
#   9. python is what type of programming language
#   10. what is the python language used for
#   11. python definition programming
#   12. what is python
#   13. what is a python code
#   14. what is a python language
#   15. what is python programming
#   16. what is python programming
#   17. what is the python
#   18. what language is python?
#   19. what is python programming language
#   20. is python dynamically typed
#   21. what is python programming
#   22. what is python
#   23. what language is python
#   24. python definition for kids
#   25. what is python language
#   26. python what is it used for
#   27. is python a python language
#   28. what is python python programming
#   29. what is python programming language
#   30. what is python language
#   31. what is python and what is it used for
#   32. what is python
#   33. what is python used for
#   34. what is python programming
#   35. what is python programming language
#   36. what is python used for
#   37. what is python
#   38. what is a python
#   39. what is python used for?
#   40. what is python?
#   41. what is python programming
#   42. what is python
#   43. is python python python
#   44. what is a python
#   45. python definition programming
#   46. what is python language
#   47. what type of language is python
#   48. what is python programming language
#   49. what is python a programming language
#   50. what is python programming
#   51. python what language
#   52. python language definition
#   53. is python a language or a framework
#   54. what is python language
#   55. what is python used for in computer science
#   56. what is a python
#   57. what is python
#   58. what is python?
#   59. what is a python?
#   60. what type of language is python
#   61. what is a python
#   62. what is python programming
#   63. what is python programming language
#   64. what is python used for
#   65. what is the python language
#   66. what is python used for
#   67. what is the python programming language
#   68. what language is python
#   69. what is python programming language
#   70. what is the python language used for
#   71. what is a python
#   72. what is python programming
#   73. what is python programming
#   74. what is python?
#   75. what is a python?
#   76. what is a python python
#   77. what is python programming
#   78. what is python programming
#   79. what is python used for
#   80. what is python programming language
# --------------------------------------------------------------------------------
# Document 6: Hypertension, or high blood pressure, can lead to severe health complications if left untreated. Com...
# Generated queries:
#   1. what causes blood pressure
#   2. can hypertension cause shortness of breath
#   3. what causes hypertension
#   4. what are the symptoms of hypertension
#   5. what are the symptoms of hypertension
#   6. what are the symptoms of hypertension
#   7. what is the symptoms of high blood pressure
#   8. hypertension symptoms
#   9. causes and symptoms of hypertension
#   10. hypertension symptoms and causes
#   11. what are the symptoms of hypertension
#   12. what causes dizziness and dizziness
#   13. hypertension symptoms in adults
#   14. what are the symptoms of hypertension
#   15. symptoms of hypertension
#   16. symptoms of hypertension in women
#   17. hypertension symptoms
#   18. what are the symptoms of hypertension
#   19. what are the signs of hypertension
#   20. what are the symptoms of hypertension
#   21. what can cause dizziness and shortness of breath
#   22. signs and symptoms of hypertension
#   23. symptoms of hypertension
#   24. what are the symptoms of hypertension
#   25. common complications of hypertension
#   26. what is a symptom of hypertension
#   27. symptoms of hypertension and their effects
#   28. symptoms of high blood pressure
#   29. symptoms of hypertension and signs of failure
#   30. what are the symptoms of hypertension
#   31. what are symptoms of hypertension
#   32. what is the medical term for hypertension
#   33. hypertension symptoms
#   34. signs of hypertensive
#   35. what causes high blood pressure and treatment
#   36. hypertension symptoms
#   37. hypertension symptoms
#   38. what are the symptoms of hypertension
#   39. what are the effects of untreated hypertension
#   40. effects of untreated hypertension
#   41. symptoms of hypertension
#   42. symptoms of hypertension
#   43. hypertension symptoms causes
#   44. symptoms of hypertension and signs of poor circulation
#   45. what can cause shortness of breath
#   46. what are the symptoms of hypertension
#   47. what causes your blood pressure to go up
#   48. what are the symptoms of hypertension
#   49. causes of severe dizziness
#   50. what are symptoms of hypertension
#   51. can you have a medical condition like hypertension
#   52. symptoms of hypertension in adults
#   53. what are the symptoms of hypertension?
#   54. what are symptoms of hypertension
#   55. symptoms of hypertension
#   56. what are the causes and symptoms of hypertension
#   57. hypertension symptoms and causes
#   58. what are the symptoms of hypertension
#   59. what are some symptoms of hypertension
#   60. symptoms of hypertension
#   61. what are symptoms of hypertension
#   62. what are the symptoms of hypertension
#   63. what are the symptoms of hypertension
#   64. what are the symptoms of hypertension
#   65. symptoms of hypertensive
#   66. causes of hypotension
#   67. hypertension symptoms
#   68. hypertension symptoms
#   69. causes and effects of hypertension
#   70. what are the effects of hypertension
#   71. can hypertension cause shortness of breath
#   72. what are the symptoms of hypertension?
#   73. what causes dizziness and lightheadedness
#   74. causes of breathing difficulties
#   75. common symptoms of hypertension
#   76. symptoms of a hypertension
#   77. what are the symptoms of hypertension
#   78. symptoms of high blood pressure in women
#   79. what does hypertension symptoms
#   80. what causes hypertension symptoms
# --------------------------------------------------------------------------------
# Document 7: The latest season of Stranger Things has captivated audiences worldwide. Critics praise its nostalgi...
# Generated queries:
#   1. what is stranger things about
#   2. what season is stranger things on
#   3. stranger things season 4 episode 7 release date
#   4. why stranger things seasons
#   5. what year is stranger things set in
#   6. what year does stranger things take place
#   7. what season is stranger things on
#   8. what's the latest season of stranger things
#   9. what's new in stranger things
#   10. what is the current season of stranger things
#   11. is stranger things a nostalgic show
#   12. stranger things latest season how many episodes
#   13. what year does stranger things take place
#   14. what is the newest season of stranger things
#   15. what season is stranger things on
#   16. what year is stranger things set
#   17. what season of stranger things is it
#   18. when will stranger things return
#   19. what's the latest season of stranger things
#   20. what season of stranger things
#   21. what season is stranger things
#   22. what is the latest season of stranger things
#   23. what genre is stranger things
#   24. why stranger things is a nostalgic show
#   25. what season of stranger things has the most nostalgic feel
#   26. what season of stranger things
#   27. when is the stranger things new season
#   28. is stranger things coming back
#   29. stranger things latest season
#   30. what season is stranger things on
#   31. why is stranger things so good
#   32. what season of stranger things is the latest
#   33. when does stranger things come out
#   34. how many seasons of stranger things
#   35. what is the plot of stranger things
#   36. what is the theme song for stranger things
#   37. how many seasons of stranger things
#   38. what is stranger things
#   39. what season of stranger things is the latest
#   40. how many seasons are there of stranger things
#   41. when does stranger things come out on tv
#   42. what does stranger things take place in
#   43. when will stranger things return
#   44. when will stranger things start again
#   45. what is the latest season of stranger things
#   46. what year is stranger things
#   47. what is stranger things about
#   48. what's going on with stranger things
#   49. what year does stranger things take place
#   50. is stranger things the latest season
#   51. what year does stranger things take place
#   52. what season is stranger things
#   53. what season is stranger things
#   54. how many seasons in stranger things
#   55. what year is stranger things
#   56. why is stranger things so addictive
#   57. how many seasons of stranger things are there
#   58. what season of stranger things
#   59. what genre is stranger things
#   60. what season is stranger things on?
#   61. what is the latest season of stranger things
#   62. is stranger things 3 coming out
#   63. why is stranger things getting cancelled
#   64. what genre is stranger things
#   65. what season of stranger things is it
#   66. stranger things episodes by season
#   67. is stranger things going to be the last season
#   68. what is stranger things about
#   69. what season of stranger things is set in the 80s
#   70. what is stranger things about
#   71. what year is stranger things set
#   72. what year is stranger things set in
#   73. is stranger things the best tv show ever
#   74. stranger things season 4 latest episode
#   75. what is the episode number for stranger things
#   76. how many seasons of stranger things are there
#   77. why stranger things is a nostalgic series
#   78. why is stranger things so good
#   79. what is the name of the season stranger things
#   80. what genre is stranger things
# --------------------------------------------------------------------------------
# Document 8: Real Madrid is one of the most successful football clubs in history, boasting multiple UEFA Champion...
# Generated queries:
#   1. most successful football club in history
#   2. most successful football teams
#   3. what is the most successful football club
#   4. most successful football teams
#   5. what is the most successful football team
#   6. most successful football club history
#   7. most successful madrid football clubs
#   8. what team does cristiano ronaldo play for
#   9. most successful football teams
#   10. most successful football team in history
#   11. who are the most successful football club
#   12. what is madrid famous for
#   13. what is the most successful football club
#   14. most successful football clubs in history
#   15. most successful football teams in history
#   16. who is the most successful football player of all time
#   17. most successful football team
#   18. most successful teams in history
#   19. most successful football club history
#   20. what is real madrid
#   21. most successful football team in history
#   22. what is real madrid famous for
#   23. most successful football clubs
#   24. what is real madrid known for
#   25. most successful football clubs in history
#   26. what is madrid famous for
#   27. most successful football teams
#   28. what is real madrid known for
#   29. what football club is cristiano ronaldo from
#   30. what is real madrid known for
#   31. what is real madrid known for
#   32. what is real madrid
#   33. what is real madrid?
#   34. what is real madrid
#   35. what is the most successful team in soccer
#   36. most successful football clubs
#   37. what kind of football does madrid play
#   38. most successful football club history
#   39. what's the most successful football team
#   40. most successful football clubs
#   41. most successful football teams
#   42. most successful football club history
#   43. most successful football teams in history
#   44. what is real madrid known for
#   45. most successful football club
#   46. most successful madrid club
#   47. most successful football clubs in history
#   48. who is the real madrid
#   49. what is real madrid
#   50. what is real madrid famous for
#   51. most successful football team
#   52. what is the real madrid
#   53. what kind of football team is real madrid
#   54. what is real madrid famous for
#   55. most successful football clubs
#   56. most successful madrid team
#   57. most successful spanish football club
#   58. what's the most successful football club
#   59. who is real madrid
#   60. what is real madrid known for
#   61. what is real madrid known for
#   62. most successful football team
#   63. most successful football clubs in history
#   64. what is the real madrid known for
#   65. most successful football clubs
#   66. most successful football club
#   67. who is real madrid
#   68. what is the most successful football club in history
#   69. most successful soccer teams
#   70. most successful football team
#   71. what football team has the most champions
#   72. most successful football club in the world
#   73. what is real madrid known for
#   74. most successful football clubs
#   75. what is real madrid known for
#   76. most successful football teams
#   77. most successful football clubs
#   78. what city is real madrid based
#   79. what is real madrid known for
#   80. what is real madrid known for
# --------------------------------------------------------------------------------
# Document 9: Cloud computing allows users to store and access data remotely, reducing dependency on local storage...
# Generated queries:
#   1. what is cloud computing computing
#   2. what is the benefits of cloud computing
#   3. what does cloud computing mean?
#   4. what is a cloud platform
#   5. what are the benefits of cloud computing
#   6. who provides cloud computing
#   7. which cloud service providers are available
#   8. what are advantages of cloud computing
#   9. what are cloud computing services
#   10. what is cloud based services
#   11. what is cloud storage used for
#   12. what cloud services provide data storage
#   13. types of cloud storage
#   14. what is cloud computing used for
#   15. what is cloud computing provider
#   16. what are the benefits of using cloud computing?
#   17. what is a cloud service provider
#   18. what is cloud computing used for
#   19. what is cloud computing?
#   20. what is cloud storage for computers
#   21. what cloud service do you use
#   22. which company provides cloud computing services
#   23. what is a cloud provider
#   24. what is cloud computing service
#   25. what is the cloud computing service
#   26. what is cloud computing service
#   27. why cloud computing is important
#   28. what is a cloud based storage service
#   29. which cloud service providers
#   30. which cloud service providers are available?
#   31. what is the cloud computing service
#   32. what does cloud computing mean
#   33. types of cloud storage solutions
#   34. what is a cloud computing system
#   35. what is the difference between cloud and on-premises
#   36. what is cloud computing and why use it
#   37. what is the advantages of cloud computing
#   38. what is a cloud provider
#   39. what are cloud providers
#   40. what is cloud computing used for
#   41. what is cloud computing and why is it important
#   42. what is the purpose of cloud computing
#   43. what is the cloud computing industry
#   44. what is cloud storage for microsoft
#   45. who owns cloud computing
#   46. what is cloud computing providers
#   47. what is cloud computing provider
#   48. what is a cloud storage system
#   49. what does cloud computing mean
#   50. what is cloud computing like
#   51. what is cloud computing example
#   52. what is cloud computing provider
#   53. who is a provider of cloud services?
#   54. what does cloud computing mean for businesses
#   55. why cloud computing is important
#   56. what is cloud computing used for
#   57. what is a cloud platform for computing
#   58. what is cloud computing used for
#   59. what is cloud computing with example
#   60. what does cloud computing mean
#   61. which cloud provider is scalable
#   62. which cloud provider has the most scalable infrastructure
#   63. what are cloud services used for
#   64. types of cloud computing
#   65. what is cloud computing for businesses
#   66. what is cloud computing used for
#   67. what is the cloud computer
#   68. what is cloud computing service provider
#   69. which cloud services is best for remote access
#   70. what is a cloud platform for business
#   71. what are cloud computing providers
#   72. what cloud providers are available
#   73. cloud computing definition and example
#   74. what is cloud based services
#   75. what are the benefits of cloud computing for small businesses
#   76. what cloud computing
#   77. what cloud computing services are available
#   78. what is cloud computing used for?
#   79. what are the main benefits of cloud computing
#   80. what is cloud computing wikipedia
# --------------------------------------------------------------------------------
# Document 10: JavaScript is a versatile programming language used primarily for web development. It enables dynami...
# Generated queries:
#   1. what is js used for
#   2. what is js?
#   3. what is the use of javascript
#   4. what is javascript used for
#   5. what is the use of javascript
#   6. what is js
#   7. what is javascript used for
#   8. what is javascript used for
#   9. what is js
#   10. what language is js
#   11. what is javascript
#   12. what is javascript used for
#   13. what is js used for
#   14. what is js
#   15. what is a javascript
#   16. what is javascript?
#   17. what is a js?
#   18. what is javascript used for?
#   19. what is javascript programming used for
#   20. what is javascript
#   21. what is js programming
#   22. what is javascript for
#   23. what is js?
#   24. what is javascript used for
#   25. what is js used for
#   26. what is javascript used for?
#   27. what is javascript used for
#   28. what is js used for
#   29. what is javascript used for in web development
#   30. what is the use of javascript
#   31. what is js used for
#   32. what is javascript used for
#   33. what is javascript used for
#   34. what is the javascript
#   35. what is js?
#   36. what is js
#   37. what is js
#   38. what is js and react
#   39. what is javascript used for
#   40. what is javascript used for
#   41. what is the use of javascript
#   42. what is javascript?
#   43. what is javascript
#   44. what is javascript used for
#   45. what is javascript used for
#   46. what is js language
#   47. what is the use of javascript
#   48. what is javascript used for
#   49. what is the purpose of javascript
#   50. what is js?
#   51. what language is javascript
#   52. what is js?
#   53. what is js used for
#   54. what are javascript
#   55. what is javascript used for
#   56. what is js used for
#   57. what is js used for
#   58. what is js
#   59. what is js
#   60. what is js used for
#   61. what language is used to create a web page
#   62. what is javascript used for
#   63. what is js used for
#   64. what is javascript used for
#   65. what are the use of javascript
#   66. what is javascript used for
#   67. what is javascript used for
#   68. what is a javascript?
#   69. what is javascript?
#   70. what is javascript used for
#   71. what is the language of react js
#   72. what is a javascript
#   73. what is js
#   74. what is js programming used for
#   75. what is a javascript
#   76. what is the javascript programming
#   77. what is javascript?
#   78. what is js programming used for
#   79. what is javascript used for
#   80. what is the use of javascript
# --------------------------------------------------------------------------------

# %%
document = "The presence of communication amid scientific minds was equally important to the success of the Manhattan Project as scientific intellect was. The only cloud hanging over the impressive achievement of the atomic researchers and engineers is what their success truly meant; hundreds of thousands of innocent lives obliterated."
test_documents = [document]

# %%
# 2. Test batch processing with multiple queries per document
print("\nBATCH PROCESSING (80 queries per document):")
print("-" * 80)
results = batch_generate_queries_vllm(test_documents, num_queries=80)

for i, doc_queries in enumerate(results):
    print(f"Document {i+1}: {test_documents[i][:100]}...")
    print("Generated queries:")
    for j, query in enumerate(doc_queries):
        print(f"  {j+1}. {query}")
    print("-" * 80)
# Out:
# BATCH PROCESSING (80 queries per document):
# --------------------------------------------------------------------------------
# Processed prompts:   1%|▏         | 1/80 [00:00<00:57,  1.37it/s, est. speed input: 91.82 toks/s, output: 1210.03 toks/s]
# Document 1: The presence of communication amid scientific minds was equally important to the success of the Manh...
# Generated queries:
#   1. what was the significance of the manhattan project
#   2. what did the united states use for the manhattan project
#   3. what was an important factor in the success of the atomic bomb project
#   4. how important was communication for the scientists
#   5. why was the manhattan project significant
#   6. what is a scientific intellect
#   7. what is the significance of manhattan project?
#   8. what was the significance of the manhattan project
#   9. significance of manhattan project
#   10. why was the manhattan project so important to americans
#   11. what caused the success of the atomic bomb
#   12. what impact did scientists have on the manhattan project
#   13. how did the success of the manhattan project impacted american society
#   14. what were the challenges of working on the manhattan project?
#   15. why was the manhattan project important
#   16. what was the manhattan project's major achievement
#   17. was the development of the atomic bomb an important part of the manhattan project
#   18. what are some important accomplishments of the scientific community in the development of the atomic bomb
#   19. why was the development of the atomic bomb so significant
#   20. the only cloud hanging over the success of the atomic researchers and engineers was
#   21. why was the success of the manhattan project so important
#   22. what was the manhattan project
#   23. why the manhattan project is a success
#   24. what was the manhattan project used for
#   25. how did science contribute to the success of the manhattan project?
#   26. manhattan project what was the success
#   27. was the scientific community involved in the manhattan project?
#   28. why was the manhattan project an achievement
#   29. what important decisions were made to guide the manhattan project
#   30. what was the importance of the manhattan project
#   31. what is the significance of the manhattan project
#   32. why was it called the manhattan project
#   33. how did the manhattan project contribute to the united states getting atomic bombs
#   34. what was the role of manhattan project
#   35. what was the impact of the manhattan project
#   36. what impact did the manhattan project have on world history
#   37. what did scientists learn from the manhattan project?
#   38. how did scientific mindset benefit the manhattan project
#   39. what was the significance of the manhattan project
#   40. the benefits of the manhattan project was greater than the benefits of the war.
#   41. is the manhattan project considered science
#   42. what impact did scientists have on the manhattan project
#   43. how many lives were lost for the atomic bomb
#   44. was there enough scientific minds to contribute to the manhattan project?
#   45. what impact did the scientists have in the manhattan project
#   46. what happened in the manhattan project
#   47. why was it so important that scientists were involved in the manhattan project
#   48. was the manhattan project successful
#   49. what was the significance of the project atomic bomb?
#   50. what was the importance of the manhattan project
#   51. why was the development of the atomic bomb a success
#   52. what was the impact of the manhattan project on society
#   53. why was the discovery of the atomic bomb so important? how does it relate to the success of the manhattan project?
#   54. why was the manhattan project important to world history
#   55. importance of communication in the manhattan project
#   56. the importance of communication in science
#   57. was the manhattan project related to communication
#   58. how did scientists play a role in the manhattan project
#   59. why was the manhattan project so successful?
#   60. what was the success of the manhattan project
#   61. what was the importance of the scientific community during the manhattan project
#   62. why was the manhattan project so important
#   63. what is the significance of the manhattan project
#   64. how many lives did the atomic bomb affect
#   65. was the manhattan project successful?
#   66. what is the significance of the manhattan project
#   67. why did manhattan project have a major impact on world history
#   68. how did the research for the manhattan project contribute to the development of the atomic bomb
#   69. what did the manhattan project have to do with the atomic bomb
#   70. what was special about the scientists involved in the manhattan project?
#   71. what was the significance of the manhattan project?
#   72. what impact did the scientific knowledge of atomic energy had on society
#   73. why did people develop the atomic bomb
#   74. what is the significance of the manhattan project?
#   75. what did the scientists do for the manhattan project
#   76. was the manhattan project the same as scientific achievement
#   77. what the importance of the manhattan project
#   78. what was the significance of the atomic bomb?
#   79. was the manhattan project about the atomic bomb?
#   80. what impact did the manhattan project have on the united states
# --------------------------------------------------------------------------------

# %%
results[0]
# Out:
# ['what was the significance of the manhattan project',
#  'what did the united states use for the manhattan project',
#  'what was an important factor in the success of the atomic bomb project',
#  'how important was communication for the scientists',
#  'why was the manhattan project significant',
#  'what is a scientific intellect',
#  'what is the significance of manhattan project?',
#  'what was the significance of the manhattan project',
#  'significance of manhattan project',
#  'why was the manhattan project so important to americans',
#  'what caused the success of the atomic bomb',
#  'what impact did scientists have on the manhattan project',
#  'how did the success of the manhattan project impacted american society',
#  'what were the challenges of working on the manhattan project?',
#  'why was the manhattan project important',
#  "what was the manhattan project's major achievement",
#  'was the development of the atomic bomb an important part of the manhattan project',
#  'what are some important accomplishments of the scientific community in the development of the atomic bomb',
#  'why was the development of the atomic bomb so significant',
#  'the only cloud hanging over the success of the atomic researchers and engineers was',
#  'why was the success of the manhattan project so important',
#  'what was the manhattan project',
#  'why the manhattan project is a success',
#  'what was the manhattan project used for',
#  'how did science contribute to the success of the manhattan project?',
#  'manhattan project what was the success',
#  'was the scientific community involved in the manhattan project?',
#  'why was the manhattan project an achievement',
#  'what important decisions were made to guide the manhattan project',
#  'what was the importance of the manhattan project',
#  'what is the significance of the manhattan project',
#  'why was it called the manhattan project',
#  'how did the manhattan project contribute to the united states getting atomic bombs',
#  'what was the role of manhattan project',
#  'what was the impact of the manhattan project',
#  'what impact did the manhattan project have on world history',
#  'what did scientists learn from the manhattan project?',
#  'how did scientific mindset benefit the manhattan project',
#  'what was the significance of the manhattan project',
#  'the benefits of the manhattan project was greater than the benefits of the war.',
#  'is the manhattan project considered science',
#  'what impact did scientists have on the manhattan project',
#  'how many lives were lost for the atomic bomb',
#  'was there enough scientific minds to contribute to the manhattan project?',
#  'what impact did the scientists have in the manhattan project',
#  'what happened in the manhattan project',
#  'why was it so important that scientists were involved in the manhattan project',
#  'was the manhattan project successful',
#  'what was the significance of the project atomic bomb?',
#  'what was the importance of the manhattan project',
#  'why was the development of the atomic bomb a success',
#  'what was the impact of the manhattan project on society',
#  'why was the discovery of the atomic bomb so important? how does it relate to the success of the manhattan project?',
#  'why was the manhattan project important to world history',
#  'importance of communication in the manhattan project',
#  'the importance of communication in science',
#  'was the manhattan project related to communication',
#  'how did scientists play a role in the manhattan project',
#  'why was the manhattan project so successful?',
#  'what was the success of the manhattan project',
#  'what was the importance of the scientific community during the manhattan project',
#  'why was the manhattan project so important',
#  'what is the significance of the manhattan project',
#  'how many lives did the atomic bomb affect',
#  'was the manhattan project successful?',
#  'what is the significance of the manhattan project',
#  'why did manhattan project have a major impact on world history',
#  'how did the research for the manhattan project contribute to the development of the atomic bomb',
#  'what did the manhattan project have to do with the atomic bomb',
#  'what was special about the scientists involved in the manhattan project?',
#  'what was the significance of the manhattan project?',
#  'what impact did the scientific knowledge of atomic energy had on society',
#  'why did people develop the atomic bomb',
#  'what is the significance of the manhattan project?',
#  'what did the scientists do for the manhattan project',
#  'was the manhattan project the same as scientific achievement',
#  'what the importance of the manhattan project',
#  'what was the significance of the atomic bomb?',
#  'was the manhattan project about the atomic bomb?',
#  'what impact did the manhattan project have on the united states']

# %%
results_str = ' '.join(results[0])

# %%
results_str
# Out:
# "what was the significance of the manhattan project what did the united states use for the manhattan project what was an important factor in the success of the atomic bomb project how important was communication for the scientists why was the manhattan project significant what is a scientific intellect what is the significance of manhattan project? what was the significance of the manhattan project significance of manhattan project why was the manhattan project so important to americans what caused the success of the atomic bomb what impact did scientists have on the manhattan project how did the success of the manhattan project impacted american society what were the challenges of working on the manhattan project? why was the manhattan project important what was the manhattan project's major achievement was the development of the atomic bomb an important part of the manhattan project what are some important accomplishments of the scientific community in the development of the atomic bomb why was the development of the atomic bomb so significant the only cloud hanging over the success of the atomic researchers and engineers was why was the success of the manhattan project so important what was the manhattan project why the manhattan project is a success what was the manhattan project used for how did science contribute to the success of the manhattan project? manhattan project what was the success was the scientific community involved in the manhattan project? why was the manhattan project an achievement what important decisions were made to guide the manhattan project what was the importance of the manhattan project what is the significance of the manhattan project why was it called the manhattan project how did the manhattan project contribute to the united states getting atomic bombs what was the role of manhattan project what was the impact of the manhattan project what impact did the manhattan project have on world history what did scientists learn from the manhattan project? how did scientific mindset benefit the manhattan project what was the significance of the manhattan project the benefits of the manhattan project was greater than the benefits of the war. is the manhattan project considered science what impact did scientists have on the manhattan project how many lives were lost for the atomic bomb was there enough scientific minds to contribute to the manhattan project? what impact did the scientists have in the manhattan project what happened in the manhattan project why was it so important that scientists were involved in the manhattan project was the manhattan project successful what was the significance of the project atomic bomb? what was the importance of the manhattan project why was the development of the atomic bomb a success what was the impact of the manhattan project on society why was the discovery of the atomic bomb so important? how does it relate to the success of the manhattan project? why was the manhattan project important to world history importance of communication in the manhattan project the importance of communication in science was the manhattan project related to communication how did scientists play a role in the manhattan project why was the manhattan project so successful? what was the success of the manhattan project what was the importance of the scientific community during the manhattan project why was the manhattan project so important what is the significance of the manhattan project how many lives did the atomic bomb affect was the manhattan project successful? what is the significance of the manhattan project why did manhattan project have a major impact on world history how did the research for the manhattan project contribute to the development of the atomic bomb what did the manhattan project have to do with the atomic bomb what was special about the scientists involved in the manhattan project? what was the significance of the manhattan project? what impact did the scientific  ...

# %%
unique_joined = document

for words in results_str.split():
    if words not in unique_joined:
        unique_joined += words
        unique_joined += " "

# %%
unique_joined
# Out:
# "The presence of communication amid scientific minds was equally important to the success of the Manhattan Project as scientific intellect was. The only cloud hanging over the impressive achievement of the atomic researchers and engineers is what their success truly meant; hundreds of thousands of innocent lives obliterated.significance manhattan project did united states use for factor bomb how scientists why significant project? so americans caused impact have impacted society were challenges working project's major development part are some accomplishments community science contribute involved decisions made guide importance called getting bombs role world history learn from mindset benefit benefits greater than war. considered many lost there enough happened that successful bomb? discovery important? does relate related play successful? during affect with special about knowledge energy had people same "

# %%
document
# Out:
# 'The presence of communication amid scientific minds was equally important to the success of the Manhattan Project as scientific intellect was. The only cloud hanging over the impressive achievement of the atomic researchers and engineers is what their success truly meant; hundreds of thousands of innocent lives obliterated.'
