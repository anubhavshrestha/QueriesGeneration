# %%
# Set this at the very start of your notebook
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Use RTX 3090 Ti

# Now import other libraries
import torch
import gc

# Clear GPU memory
torch.cuda.empty_cache()
gc.collect()

# Verify we're using the right GPU
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Device count: {torch.cuda.device_count()}")
print(f"Device name: {torch.cuda.get_device_name(0)}")
print(f"Total memory: {torch.cuda.get_device_properties(0).total_memory / (1024**3):.1f} GB")
# Out:
# CUDA available: True
# Device count: 1
# Device name: NVIDIA GeForce RTX 3090 Ti
# Total memory: 23.7 GB

# %%
# !pip install unsloth transformers datasets tqdm accelerate bitsandbytes
# Out:
# Requirement already satisfied: unsloth in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (2025.3.18)
# Requirement already satisfied: transformers in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (4.48.2)
# Requirement already satisfied: datasets in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (3.1.0)
# Requirement already satisfied: tqdm in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: accelerate in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: bitsandbytes in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (0.45.0)
# Requirement already satisfied: requests in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: filelock in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: pyyaml>=5.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: packaging>=20.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (0.26.5)
# Requirement already satisfied: safetensors>=0.4.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: numpy>=1.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: xxhash in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: aiohttp in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (3.11.10)
# Requirement already satisfied: multiprocess<0.70.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from datasets) (2024.9.0)
# Requirement already satisfied: torch>=1.10.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: psutil in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from accelerate) (6.1.0)
# Requirement already satisfied: typing_extensions>=4.8.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: propcache>=0.2.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.3.1.170)
# Requirement already satisfied: sympy==1.13.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.21.5)
# Requirement already satisfied: jinja2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.4.5.8)
# Requirement already satisfied: networkx in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /drive_reader/as16386/llama3.2/proj_env/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)

# %%
import os
import torch
import random
import numpy as np
from datasets import Dataset
from tqdm.notebook import tqdm


from transformers import TrainingArguments, DataCollatorForSeq2Seq
from trl import SFTTrainer

# Set random seed for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

# %%
# Set the path to your document-query TSV file
data_path = "/drive_reader/as16386/collections/msmarco-passage/document-query-pairs.train.tsv"  # Adjust this path

# Function to load a sample of data from the TSV file
def load_doc_query_sample(file_path, num_samples=2000):
    documents = []
    queries = []
    
    with open(file_path, 'r', encoding='utf-8') as f:
        # Read all lines and randomly sample
        lines = f.readlines()
        
        # Randomly sample num_samples lines
        if len(lines) > num_samples:
            lines = random.sample(lines, num_samples)
        
        for line in tqdm(lines, desc="Loading data"):
            parts = line.strip().split('\t')
            if len(parts) == 2:
                documents.append(parts[0])
                queries.append(parts[1])
    
    return {"document": documents, "query": queries}

# Load a small sample of data
sample_data = load_doc_query_sample(data_path, num_samples=2000)
dataset = Dataset.from_dict(sample_data)

# Let's see a few examples
print(f"Loaded {len(dataset)} document-query pairs")
print("\nExample 1:")
print(f"Document: {dataset[0]['document'][:200]}...")
print(f"Query: {dataset[0]['query']}")

print("\nExample 2:")
print(f"Document: {dataset[1]['document'][:200]}...")
print(f"Query: {dataset[1]['query']}")
# Out:
# Loading data:   0%|          | 0/2000 [00:00<?, ?it/s]
# Loaded 2000 document-query pairs
#
# Example 1:
# Document: Diabetes also can causes problems with blood flow ... The ulcer itself is usually caused by: Repetitive trauma or pressure on the foot; Puncture wound on the foot; Objects in the ... Tell your doctor ...
# Query: what causes legs to swell and acne and have blisters
#
# Example 2:
# Document: However, many fans can recall that shows do not get cancelled because of ratings alone. According to the publication, Blue Bloods Season 7 may be its last or close to the finale because the production...
# Query: was blue bloods cancelled

# %%
# Training

import torch
import random
from datasets import Dataset
from transformers import (
    AutoModelForCausalLM, 
    AutoTokenizer, 
    BitsAndBytesConfig,
    TrainingArguments,
    DataCollatorForSeq2Seq,
    Trainer
)
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from tqdm.auto import tqdm

# Set random seed for reproducibility
random.seed(42)
torch.manual_seed(42)

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Model configuration
MODEL_NAME = "meta-llama/Llama-3.2-1B-Instruct"  # or "meta-llama/Llama-3.2-1B-Instruct" for smaller model
OUTPUT_DIR = "doc2query-llama-3.2"
MAX_LENGTH = 512  # Maximum sequence length

# Format data for instruction fine-tuning
def generate_prompt(document, query=None):
    """Format the document and query into an instruction prompt."""
    if query:
        # For training examples with both document and expected query
        return f"[INST] Generate a search query for this document: {document} [/INST] {query}"
    else:
        # For inference (query generation)
        return f"[INST] Generate a search query for this document: {document} [/INST]"

def preprocess_function(examples):
    """Process multiple examples in the dataset."""
    prompts = [generate_prompt(doc, query) for doc, query in zip(examples["document"], examples["query"])]
    
    # Tokenize the examples
    tokenized_inputs = tokenizer(
        prompts,
        truncation=True,
        max_length=MAX_LENGTH,
        padding="max_length",
        return_tensors=None  # Change to None instead of "pt" - let the Dataset handle conversion
    )
    
    # Create labels (using list copying instead of tensor copying)
    tokenized_inputs["labels"] = [ids.copy() for ids in tokenized_inputs["input_ids"]]
    
    # Mask out the loss for the instruction part
    for i, prompt in enumerate(prompts):
        instruction_pos = prompt.find("[/INST]") + len("[/INST]")
        instruction_text = prompt[:instruction_pos]
        # Tokenize just the instruction part to find its length
        instruction_ids = tokenizer(instruction_text, add_special_tokens=False)["input_ids"]
        instruction_tok_len = len(instruction_ids)
        
        # Set the instruction part labels to -100 (ignore in loss calculation)
        tokenized_inputs["labels"][i][:instruction_tok_len] = [-100] * instruction_tok_len
    
    return tokenized_inputs

# Load tokenizer
print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Process dataset
print("Processing dataset...")
processed_dataset = dataset.map(
    preprocess_function,
    batched=True,
    remove_columns=dataset.column_names,
    desc="Processing dataset",
)

# Configure 4-bit quantization
print("Configuring quantization...")
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# Load model with quantization
print("Loading model...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    quantization_config=bnb_config,
    device_map="auto",
)

# Prepare model for training
print("Preparing model for training...")
model = prepare_model_for_kbit_training(model)

# LoRA configuration
peft_config = LoraConfig(
    r=16,  # Rank of the update matrices
    lora_alpha=32,  # Parameter for scaling
    lora_dropout=0.05,  # Dropout probability for LoRA layers
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",  # Attention matrices
        "gate_proj", "up_proj", "down_proj"      # MLP matrices
    ],
    bias="none",
    task_type="CAUSAL_LM",
)

# Apply LoRA
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# Configure training arguments
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=2,  # Adjust based on your GPU memory
    gradient_accumulation_steps=8,
    learning_rate=2e-4,
    num_train_epochs=3,
    logging_steps=10,
    save_steps=100,
    save_total_limit=3,
    warmup_ratio=0.03,
    lr_scheduler_type="cosine",
    report_to="none",  # Can use "tensorboard" or "wandb"
    bf16=True if torch.cuda.is_available() and torch.cuda.get_device_capability()[0] >= 8 else False,
    gradient_checkpointing=True,
    fp16=False,
    optim="paged_adamw_32bit",
)

# Define data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    pad_to_multiple_of=8,
    return_tensors="pt"
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=processed_dataset,
    data_collator=data_collator,
)

# Start training
print("Starting training...")
trainer.train()

# Save the model
print(f"Saving model to {OUTPUT_DIR}")
model.save_pretrained(OUTPUT_DIR)
tokenizer.save_pretrained(OUTPUT_DIR)

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

# 1. Load the fine-tuned model and tokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_path = "doc2query-llama-3.2"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path)

# Load base model with same quantization as training
model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-3.2-1B-Instruct",
    quantization_config=BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    ),
    device_map="auto",
)

# Load the LoRA weights
model = PeftModel.from_pretrained(model, model_path)
model.eval()

# 2. Define a function to generate multiple queries
def generate_multiple_queries(document, num_queries=80, max_new_tokens=30):
    prompt = f"[INST] Generate a search query for this document: {document} [/INST]"
    
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    
    # Set pad token id to eos token id if not set
    if model.config.pad_token_id is None:
        model.config.pad_token_id = model.config.eos_token_id
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=True,
            temperature=0.85,  # Slightly higher temperature for diversity
            top_p=0.92,
            top_k=50,
            num_return_sequences=num_queries,  # Generate multiple sequences
            num_beams=1,  # Must be 1 when using num_return_sequences with do_sample=True
            return_dict_in_generate=True,
            output_scores=False
        )
    
    generated_texts = tokenizer.batch_decode(outputs.sequences, skip_special_tokens=True)
    
    # Extract just the generated responses (after the instruction)
    responses = [text.split("[/INST]")[1].strip() for text in generated_texts]
    return responses

# 3. Test with one document from your dataset
# Choose an interesting document from your dataset
test_document = dataset[0]["document"]  # You could pick any index that has an interesting document
print(f"Document: {test_document[:200]}...\n")  # Show just the beginning to save space

# Generate 80 possible queries
queries = generate_multiple_queries(test_document, num_queries=80)

# Print the results
print(f"Generated {len(queries)} alternative queries:")
for i, query in enumerate(queries):
    print(f"{i+1}. {query}")

# 4. Optional: Save results to file
with open("generated_queries.txt", "w") as f:
    f.write(f"DOCUMENT:\n{test_document}\n\nGENERATED QUERIES:\n")
    for i, query in enumerate(queries):
        f.write(f"{i+1}. {query}\n")

print("\nQueries also saved to 'generated_queries.txt'")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Document: Diabetes also can causes problems with blood flow ... The ulcer itself is usually caused by: Repetitive trauma or pressure on the foot; Puncture wound on the foot; Objects in the ... Tell your doctor ...
# From v4.47 onwards, when a model cache is to be returned, `generate` will return a `Cache` instance instead by default (as opposed to the legacy tuple of tuples format). If you want to keep returning the legacy format, please set `return_legacy_cache=True`.
# Generated 80 alternative queries:
# 1. does diabetes cause ulcers
# 2. causes of ulcers in feet
# 3. what can cause the feet to blister and bleed
# 4. can sun damage cause ulcers on your feet
# 5. can diabetes cause blisters on feet
# 6. causes of foot ulcers in diabetic patients
# 7. what causes blisters on the soles of the feet
# 8. what causes foot ulcers in diabetes
# 9. what causes pain with sunlight
# 10. what causes ulcers to appear on your foot
# 11. causes of foot ulcers and blisters
# 12. causes of ulcers in the foot
# 13. what causes ulcers on the foot
# 14. causes of foot ulcers in diabetic patients
# 15. causes of foot ulcers and blisters
# 16. causes of ulcers on your feet
# 17. what causes foot ulcers
# 18. cause of ulcers in the foot
# 19. does diabetes cause blisters on feet
# 20. can light cause blisters on your feet
# 21. can diabetes cause ulcers in feet
# 22. how to tell if a foot ulcer has caused nerve damage
# 23. how does the foot affect diabetes
# 24. can diabetes cause foot ulcers
# 25. what causes the foot to feel like it has sunburn
# 26. what causes a foot ulcer
# 27. can ultrasonic cleaners cause foot ulcers
# 28. can diabetes cause foot problems
# 29. what can cause a foot ulcer
# 30. can diabetic foot ulcers cause blisters
# 31. what causes ulcers on the soles of your feet
# 32. what causes foot problems in people with diabetes
# 33. what causes foot ulcers with diabetes
# 34. can diabetes cause blisters on the feet
# 35. what are common problems with foot ulcers
# 36. causes of foot pain in diabetes
# 37. can ultraviolet light cause sunburn
# 38. can diabetes cause blisters
# 39. causes of foot ulcers diabetes
# 40. can a tanning bed cause foot ulcers
# 41. what can cause ulcers on feet
# 42. causes of foot problems with diabetes
# 43. what causes your skin to burn from sunlight
# 44. cause of foot ulcer
# 45. what can cause blisters and ulcers in feet
# 46. can diabetes cause blisters on feet
# 47. causes of foot ulcers diabetic
# 48. causes of skin ulcers on feet
# 49. what causes ulcers in the foot
# 50. how can i prevent foot problems
# 51. can a sunlamp cause blisters
# 52. causes of foot ulcers in diabetes
# 53. what causes sun damage
# 54. how can diabetes cause pain
# 55. does diabetic foot pain from tanning cause blisters
# 56. can tanning beds cause foot problems
# 57. what causes skin to become blistered
# 58. what causes foot ulcers and blisters
# 59. what can cause foot problems on the bottom
# 60. what causes the skin to blister
# 61. causes of foot ulcers
# 62. what causes blisters on feet from UV light
# 63. can sun cause blisters on feet
# 64. can diabetes cause blisters
# 65. can diabetes cause ulcers on feet
# 66. what causes foot problems
# 67. causes of foot problems with diabetes
# 68. what causes foot problems with diabetes
# 69. causes of foot ulcer diabetes
# 70. what causes blisters in the soles of your feet
# 71. cause of foot ulcers with diabetes
# 72. what causes ulcers to appear on your feet?
# 73. what causes foot ulcers
# 74. what causes ulcers on your feet
# 75. can vitamin di help with diabetes
# 76. what causes skin to turn blue with sun on
# 77. what causes blisters to form in the foot
# 78. can diabetes cause blisters on feet
# 79. can diabetes cause foot problems
# 80. does diabetes cause blisters on feet
#
# Queries also saved to 'generated_queries.txt'

# %% [markdown]
# # LORA Inference

# %%
# VLLM INFERENCE
# Install VLLM
# pip install vllm

from vllm import LLM, SamplingParams

# Step 1: Merge your LoRA weights with the base model (one-time operation)
from peft import PeftModel
import torch

# Load models
base_model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-3.2-1B-Instruct", 
    torch_dtype=torch.float16,
    device_map="auto"
)
lora_model = PeftModel.from_pretrained(base_model, "doc2query-llama-3.2")

# Merge and save
merged_model = lora_model.merge_and_unload()
merged_model.save_pretrained("doc2query-llama-3.2-merged")
tokenizer.save_pretrained("doc2query-llama-3.2-merged")

# Step 2: Use VLLM for fast inference
llm = LLM(model="doc2query-llama-3.2-merged", dtype="float16")

# For single document
def generate_query_vllm(document):
    prompt = f"[INST] Generate a search query for this document: {document} [/INST]"
    sampling_params = SamplingParams(temperature=0.8, top_p=0.9, max_tokens=30)
    outputs = llm.generate(prompt, sampling_params)
    response = outputs[0].outputs[0].text.strip()
    return response

# For batch processing - VLLM really shines here!
def batch_generate_queries_vllm(documents, num_queries=1):
    prompts = [f"[INST] Generate a search query for this document: {doc} [/INST]" for doc in documents]
    sampling_params = SamplingParams(
        temperature=0.8, 
        top_p=0.9, 
        max_tokens=30,
        n=num_queries  # Generate multiple queries per document
    )
    outputs = llm.generate(prompts, sampling_params)
    
    results = []
    for output in outputs:
        document_queries = [out.text.strip() for out in output.outputs]
        results.append(document_queries)
    
    return results
# Out:
# WARNING 03-26 07:48:31 cuda.py:81] Detected different devices in the system:
# WARNING 03-26 07:48:31 cuda.py:81] NVIDIA GeForce GT 1030
# WARNING 03-26 07:48:31 cuda.py:81] NVIDIA GeForce RTX 3090 Ti
# WARNING 03-26 07:48:31 cuda.py:81] Please make sure to set `CUDA_DEVICE_ORDER=PCI_BUS_ID` to avoid unexpected behavior.
# INFO 03-26 07:49:40 config.py:350] This model supports multiple tasks: {'generate', 'embedding'}. Defaulting to 'generate'.
# WARNING 03-26 07:49:40 arg_utils.py:1013] Chunked prefill is enabled by default for models with max_model_len > 32K. Currently, chunked prefill might not work with some features or models. If you encounter any issues, please disable chunked prefill by setting --enable-chunked-prefill=False.
# INFO 03-26 07:49:40 config.py:1136] Chunked prefill is enabled with max_num_batched_tokens=512.
# INFO 03-26 07:49:40 llm_engine.py:249] Initializing an LLM engine (v0.6.4.post1) with config: model='doc2query-llama-3.2-merged', speculative_config=None, tokenizer='doc2query-llama-3.2-merged', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=131072, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=1, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, quantization_param_path=None, device_config=cuda, decoding_config=DecodingConfig(guided_decoding_backend='outlines'), observability_config=ObservabilityConfig(otlp_traces_endpoint=None, collect_model_forward_time=False, collect_model_execute_time=False), seed=0, served_model_name=doc2query-llama-3.2-merged, num_scheduler_steps=1, chunked_prefill_enabled=True multi_step_stream_outputs=True, enable_prefix_caching=False, use_async_output_proc=True, use_cached_outputs=False, chat_template_text_format=string, mm_processor_kwargs=None, pooler_config=None)
# INFO 03-26 07:49:40 selector.py:261] Cannot use FlashAttention-2 backend for Volta and Turing GPUs.
# INFO 03-26 07:49:40 selector.py:144] Using XFormers backend.
# INFO 03-26 07:49:41 model_runner.py:1072] Starting to load model doc2query-llama-3.2-merged...
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 03-26 07:49:42 model_runner.py:1077] Loading model weights took 2.3185 GB
# INFO 03-26 07:49:42 worker.py:232] Memory profiling results: total_gpu_memory=23.68GiB initial_memory_usage=6.21GiB peak_torch_memory=6.79GiB memory_usage_post_profile=6.21GiB non_torch_memory=0.58GiB kv_cache_size=13.93GiB gpu_memory_utilization=0.90
# INFO 03-26 07:49:42 gpu_executor.py:113] # GPU blocks: 28538, # CPU blocks: 8192
# INFO 03-26 07:49:42 gpu_executor.py:117] Maximum concurrency for 131072 tokens per request: 3.48x
# INFO 03-26 07:49:43 model_runner.py:1400] Capturing cudagraphs for decoding. This may lead to unexpected consequences if the model is not static. To run the model in eager mode, set 'enforce_eager=True' or use '--enforce-eager' in the CLI.
# INFO 03-26 07:49:43 model_runner.py:1404] If out-of-memory error occurs during cudagraph capture, consider decreasing `gpu_memory_utilization` or switching to eager mode. You can also reduce the `max_num_seqs` as needed to decrease memory usage.
# INFO 03-26 07:49:53 model_runner.py:1518] Graph capturing finished in 11 secs, took 0.50 GiB

# %%
# Test documents (replace with your own examples)
test_documents = [
    "Diabetes also can causes problems with blood flow. The ulcer itself is usually caused by: Repetitive trauma or pressure on the foot; Puncture wound on the foot. Tell your doctor if you have any of these symptoms: Sores, ulcers, or blisters on the foot or lower leg; Pain.",
    
    "However, many fans can recall that shows do not get cancelled because of ratings alone. According to the publication, Blue Bloods Season 7 may be its last or close to the finale because the production costs are getting too high.",
    
    "The Golden State Warriors are an American professional basketball team based in San Francisco. The Warriors compete in the National Basketball Association (NBA), as a member of the league's Western Conference Pacific Division.",
    
    "Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.",
    
    "Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation. Python is dynamically typed and garbage-collected.",

    "Hypertension, or high blood pressure, can lead to severe health complications if left untreated. Common symptoms include headaches, shortness of breath, and dizziness. Lifestyle changes and medication can help manage the condition effectively.",

    "The latest season of Stranger Things has captivated audiences worldwide. Critics praise its nostalgic 80s references and compelling storytelling. However, some fans argue that the pacing in the latest episodes feels slower compared to previous seasons.",

    "Real Madrid is one of the most successful football clubs in history, boasting multiple UEFA Champions League titles. Known for their attacking playstyle, the club has produced legends like Cristiano Ronaldo, Zinedine Zidane, and Raúl.",

    "Cloud computing allows users to store and access data remotely, reducing dependency on local storage. Major providers like Amazon Web Services (AWS), Google Cloud, and Microsoft Azure dominate the market with their scalable infrastructure.",

    "JavaScript is a versatile programming language used primarily for web development. It enables dynamic interactions on web pages and is supported by all major browsers. Frameworks like React and Angular simplify the development process."




]

# %%
# 2. Test batch processing with multiple queries per document
print("\nBATCH PROCESSING (80 queries per document):")
print("-" * 80)
results = batch_generate_queries_vllm(test_documents, num_queries=80)

for i, doc_queries in enumerate(results):
    print(f"Document {i+1}: {test_documents[i][:100]}...")
    print("Generated queries:")
    for j, query in enumerate(doc_queries):
        print(f"  {j+1}. {query}")
    print("-" * 80)
# Out:
# BATCH PROCESSING (80 queries per document):
# --------------------------------------------------------------------------------
# Processed prompts:   0%|          | 0/800 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts:   1%|▏         | 10/800 [00:02<03:24,  3.86it/s, est. speed input: 224.08 toks/s, output: 2366.86 toks/s]
# Document 1: Diabetes also can causes problems with blood flow. The ulcer itself is usually caused by: Repetitive...
# Generated queries:
#   1. diabetes causes blood flow problems
#   2. causes of ulcer on the foot with diabetes
#   3. what causes ulcers on the foot
#   4. causes of a foot ulcer
#   5. diabetes causes blood flow to be blocked
#   6. what causes ulcers on the soles of your feet
#   7. how to tell if you have diabetes in your foot
#   8. what causes ulcers in the foot diabetes
#   9. what causes diabetic foot ulcers
#   10. what causes blisters on your feet diabetic neuropathy
#   11. causes of poor blood flow in the feet
#   12. causes of ulcer on the foot
#   13. what causes diabetes foot ulcers
#   14. diabetes causes ulcers in feet
#   15. foot problems diabetes
#   16. which can cause ulcers on feet?
#   17. causes of ulcers on the foot
#   18. what causes a foot ulcer to heal
#   19. what causes ulcers to form on your feet
#   20. causes of ulcers in the foot
#   21. causes of blisters on feet and leg diabetic ulcers
#   22. what causes diabetic foot ulcers
#   23. diabetes causes problems with blood flow
#   24. diabetes causes foot ulcers
#   25. what causes a foot ulcer to heal
#   26. causes of ulcers on feet with diabetes
#   27. what causes a foot ulcer
#   28. what causes diabetes to cause ulcers
#   29. diabetes foot ulcers causes
#   30. diabetes cause blisters on the feet
#   31. what causes a sore foot with diabetes
#   32. can diabetes cause ulcers on your feet
#   33. how does diabetes cause ulcers
#   34. what causes diabetes to affect blood flow
#   35. what causes foot ulcers diabetes
#   36. can diabetes cause ulcers on the feet
#   37. what causes ulcers in diabetes
#   38. what causes diabetes foot ulcers
#   39. causes of foot ulcers with diabetes
#   40. what causes ulcers on your foot
#   41. causes of a foot ulcer
#   42. what causes a foot ulcer in diabetes
#   43. what causes a foot ulcer to heal
#   44. which causes blisters in foot and leg
#   45. what causes problems with blood flow to the foot
#   46. causes of a foot ulcer with diabetes
#   47. what causes ulcers in the foot diabetes
#   48. diabetes ulcer symptoms
#   49. causes of leg ulcers without diabetes
#   50. what causes blisters on the soles of your feet
#   51. how to know if your ulcers are diabetic
#   52. what causes diabetes ulcers
#   53. can diabetes cause ulcers on the bottom of your feet
#   54. what causes diabetes foot ulcers
#   55. what are causes of a foot ulcer
#   56. what are symptoms of diabetes affecting blood flow
#   57. how does diabetes cause ulcers in the feet
#   58. can diabetes cause foot ulcers
#   59. how to heal foot ulcers
#   60. causes for ulcers on the foot
#   61. causes of persistent foot ulcers
#   62. diabetes causes problems with blood flow
#   63. what causes diabetic foot ulcers
#   64. causes of foot ulcers that are diabetic
#   65. causes of foot ulcers with diabetes
#   66. what causes diabetes to cause foot problems
#   67. what causes foot ulcers from diabetes
#   68. what causes ulcer in foot
#   69. what causes foot ulcers to form in diabetes
#   70. what causes foot ulcers diabetes
#   71. causes of ulcers on feet
#   72. what causes a foot ulcer
#   73. can diabetes cause ulcers on your feet
#   74. diabetes causing foot ulcers
#   75. what causes foot ulcers diabetes
#   76. what causes foot ulcers diabetes
#   77. can diabetes cause ulcers in feet
#   78. what causes foot ulcers diabetes
#   79. what causes diabetic foot ulcers
#   80. foot problems diabetes
# --------------------------------------------------------------------------------
# Document 2: However, many fans can recall that shows do not get cancelled because of ratings alone. According to...
# Generated queries:
#   1. is blue bloods cancelled
#   2. why is blue bloods ending
#   3. blue bloods cancelled
#   4. why did blue bloods end after 7 seasons
#   5. why blue bloods hasn't been renewed
#   6. did blue bloods end after season 7
#   7. was blue bloods cancelled
#   8. when was blue bloods renewed
#   9. why was blue bloods cancelled
#   10. is blue bloods cancelled
#   11. blue bloods season 7 last
#   12. blue bloods cancelled
#   13. how long blue bloods has been on
#   14. blue bloods ratings cancelled
#   15. is blue bloods last season
#   16. why is blue bloods cancelled
#   17. blue bloods season 7 cancelled
#   18. why blue bloods cancelled
#   19. what causes shows to get cancelled
#   20. why blue bloods cancelled
#   21. why is blue bloods cancelled
#   22. when is blue bloods last season
#   23. blue bloods cancelled
#   24. blue bloods cancellation
#   25. blue bloods cancelled season
#   26. is blue bloods season 7 going to be cancelled
#   27. blue bloods season 7 cancelled
#   28. is blue bloods cancelled
#   29. is blue bloods getting cancelled
#   30. what is blue bloods last season
#   31. how many seasons blue bloods
#   32. blue bloods season 7 cancelled
#   33. when is blue bloods gonna end
#   34. is blue bloods ending
#   35. did blue bloods cancel or renew
#   36. is blue bloods cancelled or renewed
#   37. when was blue bloods cancelled
#   38. is blue bloods getting cancelled
#   39. is blue bloods ending
#   40. why blue bloods has not gotten cancelled
#   41. how many seasons blue bloods have been made
#   42. is blue bloods going to have another season
#   43. what tv show is cancelled because of low ratings
#   44. blue bloods cancellation
#   45. is blue bloods cancelled
#   46. when is blue bloods season 7 finale
#   47. blue bloods ratings dropped
#   48. is blue bloods going to be renewed
#   49. is blue bloods going to end
#   50. blue bloods ratings reasons why they stopped
#   51. why is blue bloods cancelled
#   52. why is blue bloods cancelled
#   53. when is blue bloods going to end
#   54. is blue bloods cancelled
#   55. why blue bloods cancelled
#   56. why did blue bloods cancel
#   57. why is blue bloods cancelled
#   58. why did blue bloods cancel
#   59. is blue bloods last season
#   60. blue bloods season 7 cancellation
#   61. blue bloods cancelled or renewed
#   62. is blue bloods ending?
#   63. blue bloods ratings why is blue bloods cancelled
#   64. blue bloods ratings dropped
#   65. is blue bloods cancelled
#   66. is blue bloods canceled
#   67. is blue bloods on renewal
#   68. blue bloods season 7 may be canceled
#   69. blue bloods season 7 ratings
#   70. blue bloods season 7 finale
#   71. why was blue bloods cancelled
#   72. why did blue bloods end
#   73. blue bloods season finale ratings
#   74. blue bloods season finale ratings
#   75. did blue bloods end
#   76. why blue bloods cancelled
#   77. are blue bloods going to end
#   78. why is blue bloods cancelled
#   79. blue bloods cancellation
#   80. blue bloods season 7 cancelled
# --------------------------------------------------------------------------------
# Document 3: The Golden State Warriors are an American professional basketball team based in San Francisco. The W...
# Generated queries:
#   1. where is the warriors team located?
#   2. where is the warriors basketball team based
#   3. where are the warriors based?
#   4. what conference is the warriors in nba
#   5. where are the warriors based
#   6. what conference does the golden state warriors play in
#   7. where are warriors based
#   8. where is the golden state warriors based
#   9. what conference does the warriors play in
#   10. where is the golden state warriors located?
#   11. where is the golden state warriors based
#   12. what conference is the golden state warriors in
#   13. where is the warriors team based
#   14. what conference is the warriors in
#   15. where are the warriors from
#   16. what conference is warriors in
#   17. where are the warriors team
#   18. where is the golden state warriors team based
#   19. what division is the golden state warriors in
#   20. where is the golden state warriors based
#   21. where is the golden state warriors based
#   22. what conference is the warriors in
#   23. what division is the warriors in nba
#   24. where is the warriors basketball team from
#   25. where are warriors based
#   26. where is the golden warriors based?
#   27. what conference is warriors in nba
#   28. where is the golden state warriors based
#   29. where are the warriors based
#   30. what division is the golden state warriors in
#   31. where is the warriors team based?
#   32. what conference is the warriors in
#   33. where is the warriors based?
#   34. where is the golden state warriors based
#   35. what conference is the golden state warriors in
#   36. what conference is the golden state warriors in
#   37. where is the warriors based
#   38. what conference is the golden state warriors in
#   39. what conference is the golden state warriors in
#   40. where are the warriors based
#   41. where is the warriors team based
#   42. what conference is the golden state warriors in
#   43. what conference is the warriors in nba
#   44. where are the warriors based
#   45. what team is the warriors
#   46. where is the golden state warriors based
#   47. what conference is the warriors in the nba
#   48. what conference is the warriors in
#   49. where is the golden warriors based
#   50. where is the warriors team based
#   51. where is the warriors team from
#   52. where are the warriors based?
#   53. what conference is the warriors in nba
#   54. where are the warriors based
#   55. where are warriors based?
#   56. what conference does the warriors play in
#   57. what conference is the warriors in
#   58. where is the warriors basketball team based
#   59. what city is the warriors based in
#   60. where is the warriors basketball team from
#   61. where are the golden warriors from
#   62. what conference is the warriors in nba
#   63. what conference is the golden state warriors in
#   64. what division is warriors in nba
#   65. where is the warriors basketball team based
#   66. where are the warriors from
#   67. where is the warriors based
#   68. where are the warriors based?
#   69. where are the golden warriors based
#   70. what conference does warriors play in
#   71. where are the golden warriors based
#   72. where is the warriors team based?
#   73. what conference is warriors in nba
#   74. where is the warriors team
#   75. what city is the warriors basketball team in
#   76. where is the warriors team from
#   77. what conference is the golden state warriors in
#   78. where is the golden state warriors based
#   79. what conference is the warriors in
#   80. where is the warriors team based
# --------------------------------------------------------------------------------
# Document 4: Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on t...
# Generated queries:
#   1. machine learning definition
#   2. what is machine learning ai and computer science
#   3. what is machine learning definition
#   4. what is machine learning ai definition
#   5. what is machine learning in computer science
#   6. what is machine learning definition
#   7. what is machine learning and artificial intelligence
#   8. what is the difference between artificial intelligence and machine learning
#   9. what is machine learning
#   10. what is machine learning definition
#   11. what is machine learning?
#   12. what is machine learning
#   13. what is machine learning and ai?
#   14. what is machine learning?
#   15. what is machine learning?
#   16. what is machine learning ai
#   17. machine learning is also known as
#   18. what is machine learning?
#   19. what is the difference between machine learning and artificial intelligence
#   20. what is the difference between machine learning and artificial intelligence
#   21. what is machine learning?
#   22. what is machine learning in science
#   23. what is machine learning
#   24. what is machine learning?
#   25. what is machine learning
#   26. what is machine learning definition
#   27. what is the difference between machine learning and artificial intelligence
#   28. what is machine learning?
#   29. what is machine learning definition
#   30. what is machine learning and artificial intelligence
#   31. what is machine learning definition
#   32. what is machine learning technology
#   33. what is machine learning
#   34. what is the difference between machine learning and artificial intelligence
#   35. define machine learning
#   36. what is machine learning and artificial intelligence
#   37. machine learning definition and definition of artificial intelligence
#   38. what is machine learning and artificial intelligence
#   39. what is the machine learning
#   40. what is machine learning
#   41. what is machine learning
#   42. machine learning definition
#   43. machine learning is a type of what
#   44. what is machine learning definition
#   45. what is machine learning
#   46. what is machine learning? what is artificial intelligence?
#   47. what is machine learning in computer science
#   48. what is the difference between artificial intelligence and machine learning
#   49. what is machine learning
#   50. what is machine learning
#   51. what is machine learning ai
#   52. what is machine learning and how does it work
#   53. what is machine learning
#   54. what is the difference between machine learning and artificial intelligence
#   55. what is machine learning and ai
#   56. what is machine learning technology
#   57. what is machine learning definition
#   58. what is machine learning artificial intelligence
#   59. what is the definition of machine learning
#   60. machine learning definition and how it works
#   61. what is machine learning
#   62. what is machine learning ai definition
#   63. what is machine learning definition
#   64. what is machine learning in computer science
#   65. define artificial intelligence machine learning
#   66. what is the difference between machine learning and artificial intelligence
#   67. what is machine learning definition
#   68. what is machine learning definition
#   69. machine learning definition
#   70. what is machine learning
#   71. what is machine learning ai computer science
#   72. what is machine learning definition
#   73. what is the difference between machine learning and artificial intelligence
#   74. what is machine learning
#   75. define machine learning
#   76. what is machine learning?
#   77. what is machine learning ai and what is it used for
#   78. machine learning definition
#   79. machine learning definition
#   80. what is machine learning in simple terms
# --------------------------------------------------------------------------------
# Document 5: Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code ...
# Generated queries:
#   1. what is a python language
#   2. what is python programming language
#   3. what is python language
#   4. what is python language
#   5. what is python programming language
#   6. what is the purpose of python
#   7. what is a python language
#   8. what is python language
#   9. what is a general-purpose language?
#   10. what is python programming language
#   11. what is the purpose of python
#   12. what is the highest level of programming language?
#   13. what is a general purpose language in python
#   14. what is the purpose of python
#   15. what is python language type
#   16. what is python language
#   17. what is python language
#   18. what is the purpose of the indentation in python
#   19. what is a python language
#   20. what is the primary philosophy of the python language
#   21. what kind of programming language is python
#   22. what is python language
#   23. what is a python language
#   24. what is python language
#   25. what is python programming language
#   26. what is python language
#   27. what is python language
#   28. what is python language
#   29. what is python language
#   30. what is python programming language
#   31. what is python programming language
#   32. what is python language
#   33. what is the most popular python language
#   34. what is python programming language
#   35. what is a language that is a high-level language
#   36. what is python language
#   37. what is the purpose of python
#   38. what is the purpose of python
#   39. what is the purpose of python
#   40. what is a high level language
#   41. what is the purpose of python
#   42. what is the python language
#   43. what is python language
#   44. what is the type of python language
#   45. what is a python programming language
#   46. what is the purpose of python
#   47. what is python programming language
#   48. what is the purpose of python
#   49. what is python language
#   50. what is python language
#   51. what is a high level language in programming
#   52. what is the most popular python language
#   53. what is python a
#   54. what is a python language
#   55. what is a language that is easy to read and write
#   56. what is python programming language
#   57. what is python programming language
#   58. what is a general purpose language?
#   59. what is python programming language
#   60. what kind of language is python
#   61. what is python type
#   62. what is python language
#   63. what is python a programming language
#   64. what is the python language
#   65. what is python language
#   66. what is python language
#   67. what is python programming language
#   68. what is python language
#   69. what is the purpose of python
#   70. what is a python language
#   71. what is python language
#   72. what is python a
#   73. what is the purpose of the indentation in python?
#   74. what is python language
#   75. what is the purpose of python?
#   76. what is python language
#   77. what is python programming language
#   78. what is python language
#   79. what is python language
#   80. what is python programming language
# --------------------------------------------------------------------------------
# Document 6: Hypertension, or high blood pressure, can lead to severe health complications if left untreated. Com...
# Generated queries:
#   1. what is high blood pressure
#   2. what are the symptoms of uncontrolled high blood pressure
#   3. what is the medication for hypertension
#   4. what is blood pressure condition
#   5. what are the health complications of uncontrolled blood pressure
#   6. hypertension causes and symptoms
#   7. what are symptoms of uncontrolled high blood pressure
#   8. what causes high blood pressure in adults
#   9. can you get hypertension with certain medications
#   10. what causes blood pressure to go up when you exercise
#   11. what are the symptoms of hypertension
#   12. what are the symptoms of uncontrolled high blood pressure
#   13. what are the symptoms of untreated high blood pressure
#   14. what causes blood pressure to go up
#   15. what is normal blood pressure level
#   16. what does hypertension mean
#   17. causes of severe high blood pressure
#   18. what are the symptoms of uncontrolled hypertension
#   19. what does hypertension stand for
#   20. what are the symptoms of uncontrolled hypertension
#   21. hypertension causes
#   22. what is the normal blood pressure for a healthy person
#   23. what are the symptoms of untreated hypertension
#   24. can hypertension cause dizziness
#   25. what is high blood pressure symptoms
#   26. symptoms of hypertension
#   27. how to diagnose high blood pressure in children
#   28. can dehydration cause high blood pressure
#   29. can you say what high blood pressure is
#   30. what are symptoms of high blood pressure
#   31. hypertension symptoms
#   32. what are the symptoms of untreated hypertension
#   33. what causes your blood pressure to go up
#   34. what are the symptoms of uncontrolled high blood pressure
#   35. can constant blood pressure cause dizziness
#   36. hypertension and dizziness
#   37. what causes high blood pressure
#   38. what are the consequences of not treating high blood pressure
#   39. can a blood pressure of 220 help
#   40. can hypertension cause dizziness
#   41. symptoms of untreated high blood pressure
#   42. what does blood pressure mean
#   43. hypertension causes
#   44. what causes high blood pressure
#   45. what are the symptoms of untreated hypertension
#   46. how is hypertension diagnosed
#   47. what is a level of blood pressure
#   48. what is high blood pressure with symptoms
#   49. what does blood pressure of 150 mean
#   50. what causes high blood pressure
#   51. hypertension symptoms
#   52. what is hypertension
#   53. what are the symptoms of untreated high blood pressure
#   54. what causes blood pressure to go up?
#   55. what are the symptoms of untreated hypertension
#   56. what are the symptoms of uncontrolled high blood pressure
#   57. what causes high blood pressure to get worse
#   58. what are symptoms of untreated high blood pressure
#   59. how does high blood pressure cause dizziness
#   60. what causes hypertension
#   61. hypertension meaning
#   62. what does hypertension mean
#   63. how to know if you have high blood pressure
#   64. hypertension meaning
#   65. what is the blood pressure level that causes symptoms
#   66. what are the common symptoms of high blood pressure
#   67. causes of high blood pressure in adults
#   68. can taking medication for high blood pressure cause dizziness
#   69. what are the causes of high blood pressure
#   70. hypertension meaning
#   71. what causes high blood pressure in men
#   72. what are the symptoms of uncontrolled hypertension
#   73. hypertension causes
#   74. can high blood pressure cause dizziness
#   75. what causes blood pressure to rise
#   76. what does a blood pressure reading of 170 mean
#   77. what is the common cause of hypertension
#   78. hypertension causes and symptoms
#   79. what is blood pressure what does it mean
#   80. what does hypertension do to your body
# --------------------------------------------------------------------------------
# Document 7: The latest season of Stranger Things has captivated audiences worldwide. Critics praise its nostalgi...
# Generated queries:
#   1. how long does stranger things take to finish
#   2. is stranger things getting a new season?
#   3. is stranger things on netflix still?
#   4. what is the latest season of stranger things
#   5. is stranger things the best season
#   6. what season of stranger things is the latest
#   7. what season of stranger things is the latest?
#   8. why does stranger things take so long
#   9. is the latest season of stranger things more or less than the previous ones
#   10. is the stranger things season 4 going to be the last
#   11. how is stranger things season 4
#   12. what is the stranger things latest season
#   13. what is the stranger things season 4 plot
#   14. what does stranger things latest season bring
#   15. what season of stranger things is the newest
#   16. what year was stranger things made
#   17. which season of stranger things is the best
#   18. why does stranger things feel slower than the previous season
#   19. how is stranger things season 4
#   20. what season of stranger things is the latest
#   21. is stranger things on netflix
#   22. how many seasons is stranger things
#   23. what is the stranger things season 4 episode 4 titled
#   24. how many seasons of stranger things have been made
#   25. why is stranger things season 4 so hard to watch
#   26. what season of stranger things is the latest
#   27. what does stranger things latest season have
#   28. who makes stranger things
#   29. who made stranger things
#   30. is stranger things on s4 season 4?
#   31. who made stranger things
#   32. what season of stranger things is the newest
#   33. who is the star of stranger things
#   34. what season of stranger things has the best story
#   35. what season of stranger things is the latest
#   36. what season of stranger things is the latest
#   37. is stranger things on hulu
#   38. is stranger things getting a new season
#   39. what are the latest season of stranger things
#   40. what is the best season of stranger things
#   41. what does stranger things show mean
#   42. which season of stranger things has the best episodes
#   43. what season of stranger things is the newest
#   44. what is the newest season of stranger things
#   45. what season of stranger things has the best plot
#   46. is the stranger things show a good season
#   47. what season is stranger things in
#   48. what season of stranger things is most popular
#   49. is stranger things on Hulu
#   50. how many seasons of stranger things have been made
#   51. what season of stranger things is the latest
#   52. what season of stranger things is the latest
#   53. what is the best season of stranger things
#   54. what is the latest season of stranger things
#   55. what is the latest season of stranger things
#   56. is stranger things the best show on tv right now
#   57. what season is stranger things in
#   58. is stranger things the best season
#   59. what season of stranger things has the most suspense
#   60. how many seasons of stranger things have there been
#   61. what does stranger things movie have to do with the show
#   62. is stranger things a good show
#   63. which season of stranger things is the most popular
#   64. what year was stranger things released?
#   65. which season of stranger things is the best
#   66. is the stranger things season 4 the best season
#   67. what season of stranger things has the best plot
#   68. what season is stranger things on right now
#   69. which season of stranger things is the most popular
#   70. what season of stranger things is the most popular?
#   71. what season of stranger things is the latest
#   72. is stranger things on Netflix?
#   73. what season of stranger things has the most episodes
#   74. how many seasons is stranger things in
#   75. how many seasons of stranger things are there
#   76. who directed stranger things season 4
#   77. what season of stranger things is the latest
#   78. is stranger things on netflix right now
#   79. what season of stranger things is the most recent
#   80. what does stranger things mean
# --------------------------------------------------------------------------------
# Document 8: Real Madrid is one of the most successful football clubs in history, boasting multiple UEFA Champion...
# Generated queries:
#   1. which of the following is the most successful football club in the world
#   2. what are the biggest football clubs in the world
#   3. what is the most successful madrid club
#   4. what city is real madrid located in?
#   5. which football club is known for their most number of titles
#   6. what city is real madrid based
#   7. what city is real madrid football club based
#   8. what is the biggest club in world football
#   9. which club has the most champs leagues titles
#   10. which of the following is true about madrid
#   11. which of the following is the most successful club in the world?
#   12. what league is real madrid in
#   13. what is real madrid famous for
#   14. how many world cup titles does real madrid have
#   15. who is the most successful madrid club in history
#   16. what city is real madrid football club
#   17. what city is madrid located in
#   18. who is the most successful madrid club
#   19. what city is madrid in
#   20. which club is the most successful in terms of championships
#   21. what is the most successful club in the world
#   22. what is madrids greatest achievement
#   23. what is the most successful football club in history?
#   24. most successful spanish football club
#   25. what city is real madrid located in
#   26. what is the most successful club in world football?
#   27. what city is real madrid from
#   28. how many uefa champions league titles has real madrid won
#   29. which football club is real madrid
#   30. what team is real madrid
#   31. most successful football club in history
#   32. what is madrid's greatest achievement in football
#   33. what city is madrid in
#   34. what city is real madrid based in
#   35. how many world cups has real madrid won
#   36. what is the biggest club in the world
#   37. most successful football club in the world
#   38. what city is madrid located in
#   39. most successful football club in the world
#   40. what is the biggest club in world
#   41. most successful football club in history
#   42. what is the number of world cup for real madrid
#   43. which club has won the most uefa champions league
#   44. what is real madrid biggest club ever
#   45. which team has the most successful record in europe
#   46. which of the following teams is most successful in the uefa champions league
#   47. what city is real madrid football club based
#   48. most successful football club in the world
#   49. which football club is the most successful in the world
#   50. what is the most successful madrid team
#   51. what city is madrid in
#   52. what city is real madrid football club from
#   53. most successful club in world cup history
#   54. what team is madrid
#   55. what city is real madrid from
#   56. what is madrid known for
#   57. what is the most successful madrid club
#   58. what city is madrid located in
#   59. what is the most successful football club in history
#   60. what club has won most champions league
#   61. most successful madrid club
#   62. what is real madrid known for
#   63. who is the biggest madrid player
#   64. what team is cristiano ronaldo playing for
#   65. what is the most successful football club
#   66. what is the most successful club in madrid
#   67. what is the most successful football club in history
#   68. which is the most successful club in spanish football
#   69. most successful madrid team in history
#   70. what city is real madrid based
#   71. most successful football club in history
#   72. what city is real madrid from
#   73. what is the most successful team in world cup history
#   74. most successful football club in the world
#   75. what are real madrid most successful championships?
#   76. what is the most successful madrid club
#   77. what is the most successful club in the world
#   78. what is the biggest club in the world
#   79. most successful football club in history
#   80. what is the most successful madrid club
# --------------------------------------------------------------------------------
# Document 9: Cloud computing allows users to store and access data remotely, reducing dependency on local storage...
# Generated queries:
#   1. what is cloud computing and how does it work
#   2. what is cloud computing
#   3. cloud computing what is it
#   4. what is cloud computing and its benefits
#   5. what is cloud computing with aws
#   6. what is cloud computing for in business?
#   7. what is cloud computing? cloud computing is the delivery of computing resources and services over the internet, and is used for a variety of purposes, including hosting
#   8. what is cloud computing and what does it do
#   9. what cloud service provider cloud computing
#   10. what is cloud computing and who provides cloud computing
#   11. what is cloud computing and what are its benefits
#   12. what is cloud computing
#   13. what is cloud computing in a business
#   14. what is cloud computing definition
#   15. what is cloud computing and what are the benefits of cloud computing
#   16. what is cloud computing
#   17. cloud computing providers
#   18. what are the advantages of cloud computing
#   19. what is cloud computing technology
#   20. what is cloud computing and what are its benefits
#   21. what is cloud computing and how does it work
#   22. what is cloud computing and what are the benefits
#   23. cloud computing definition and benefits
#   24. what is cloud computing with examples
#   25. what is cloud computing with regards to data storage
#   26. what is cloud computing
#   27. what is cloud computing what
#   28. what is cloud computing? cloud computing is a way to use many computers to run one computer, you can access and share data and applications from many computers
#   29. what is cloud computing
#   30. what is cloud computing
#   31. what is cloud computing and who are the major players
#   32. what is cloud computing
#   33. what is cloud computing definition
#   34. what is cloud computing
#   35. what is cloud computing?
#   36. cloud computing types
#   37. what is cloud computing cloud computing is a type of data storage and computing that uses remote access to a network of servers instead of a central computer.
#   38. cloud computing definition and benefits
#   39. what is cloud computing and what is it used for
#   40. what is cloud computing benefits
#   41. what is cloud computing
#   42. what is cloud computing
#   43. what is cloud computing and how does it work
#   44. what is cloud computing definition
#   45. what is cloud computing?
#   46. what is cloud computing?
#   47. what is cloud computing
#   48. what is cloud computing
#   49. what is cloud computing?
#   50. what is cloud computing
#   51. what is cloud computing major providers
#   52. what is cloud computing and what does it do
#   53. cloud computing definition and types
#   54. what is cloud computing a?
#   55. what is cloud computing
#   56. what is cloud computing defined by
#   57. what is cloud computing and how it works
#   58. what is cloud computing for businesses
#   59. what is cloud computing?
#   60. cloud computing is
#   61. what is cloud computing
#   62. cloud computing definition, advantages
#   63. what is cloud computing
#   64. what is cloud computing
#   65. what is cloud computing with big data?
#   66. what is cloud computing? cloud computing is a model for delivering computing resources and services over the internet
#   67. what is cloud computing used for
#   68. cloud computing benefits and drawbacks
#   69. what cloud computing means
#   70. what is cloud computing
#   71. what is cloud computing for
#   72. what is cloud computing and what is it used for
#   73. what is cloud computing
#   74. what is cloud computing?
#   75. what is cloud computing definition
#   76. what is cloud computing with examples
#   77. what is cloud computing
#   78. what is cloud computing for
#   79. what are cloud computing providers
#   80. what is cloud computing defined as
# --------------------------------------------------------------------------------
# Document 10: JavaScript is a versatile programming language used primarily for web development. It enables dynami...
# Generated queries:
#   1. what is a javascript framework
#   2. what is a javascript framework
#   3. what is a javascript framework
#   4. what is javascript
#   5. what is a framework for javascript
#   6. what is the purpose of the language javascript
#   7. what is javascript used for
#   8. what are some frameworks used in javascript
#   9. what are some programming languages that are good for web development?
#   10. what is a programming language like javascript
#   11. what is the purpose of a language like javascript
#   12. what is a javascript programming language
#   13. what is javascript used for
#   14. what is the use of javascript
#   15. what is javascript used for
#   16. what is javascript programming language
#   17. what is a javascript framework
#   18. what is the purpose of javascript
#   19. what is a javascript framework
#   20. what is a javascript framework
#   21. what is a good framework for web development
#   22. what is javascript used for
#   23. what are the major benefits of using javascript
#   24. what is javascript used for
#   25. what are some common use of javascript
#   26. what is a framework for web development?
#   27. what is the purpose of the framework in javascript
#   28. what is the most commonly used programming language
#   29. what is javascript used for
#   30. what is the most widely used programming language
#   31. what is a programming language called
#   32. what is the most popular programming language
#   33. what is the best programming language for web development?
#   34. what are the most common frameworks used in web development
#   35. what is javascript used for
#   36. what is javascript used for
#   37. what is the purpose of javascript
#   38. what is javascript programming language
#   39. what is javascript programming language
#   40. what is the purpose of javascript
#   41. what is a good programming language for web development
#   42. what is javascript used for
#   43. what is a javascript framework
#   44. what is a javascript framework
#   45. what is a javascript framework
#   46. what is a browser in js
#   47. what is the use of javascript
#   48. what is the language that makes up most of the web
#   49. what is a good javascript framework
#   50. what is a javascript framework
#   51. what is the purpose of the javascript language
#   52. what is the most popular programming language used for web development?
#   53. what is a javascript framework
#   54. what is a javascript framework
#   55. what is javascript used for
#   56. what is a js framework
#   57. what is the purpose of javascript
#   58. what is a javascript
#   59. what is a framework for javascript
#   60. what is the purpose of javascript
#   61. what is a js framework
#   62. what is a language used for web development
#   63. what is the purpose of javascript
#   64. what is javascript used for
#   65. what is the most widely used programming language
#   66. what is a js framework
#   67. what is javascript and what does it do
#   68. what is a programming language for web development
#   69. what is the purpose of the language javascript
#   70. what is javascript for
#   71. what is the main use of javascript
#   72. what is a javascript framework
#   73. what is a javascript
#   74. what is javascript used for
#   75. what is the purpose of javascript
#   76. what is the purpose of javascript
#   77. what is a framework for js
#   78. what is javascript
#   79. what is javascript used for
#   80. what is the most popular language for web development
# --------------------------------------------------------------------------------
